# %% [markdown]
# ## Set Up MCP Server to Expose the Database

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, inspect
from sqlalchemy.orm import sessionmaker
import re
from models import get_tables_in_order
user = os.getenv("USER")
password = os.getenv("PASSWORD")
host = os.getenv("HOST")
port = os.getenv("PORT")
dbname = os.getenv("DATABASE")



# ---------- Database Setup ----------
DATABASE_URL = "postgresql+psycopg2://postgres:ashish6677@34.30.63.17:5432/postgres"
engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)
session = Session()

def load_csv_to_db(file_path, table_name):
    """
    Reads CSV and inserts data into Postgres table with length validation.
    """
    print(f"📂 Loading {file_path} into table '{table_name}'")

    # 1. Read CSV
    df = pd.read_csv(file_path)

    # 2. Get DB column max lengths for VARCHAR columns
    inspector = inspect(engine)
    columns_info = inspector.get_columns(table_name)
    varchar_limits = {
        col["name"]: int(re.search(r"\((\d+)\)", str(col["type"])).group(1))
        for col in columns_info
        if "VARCHAR" in str(col["type"]).upper()
    }

    # 3. Trim only values exceeding VARCHAR limits
    for col, limit in varchar_limits.items():
        if col in df.columns:
            df[col] = df[col].astype(str).apply(lambda x: x[:limit] if len(x) > limit else x)

    # 4. Push to DB (append to existing table)
    df.to_sql(table_name, engine, if_exists="append", index=False)

    print(f"✅ Inserted {len(df)} rows into {table_name}")

# ---------- Load all CSVs in schema order ----------


def load_all_csvs(csv_folder):
    table_order = get_tables_in_order()
    for table in table_order:
        print(table)
        csv_file = os.path.join(csv_folder, f"{table}.csv")
        if os.path.exists(csv_file):
            load_csv_to_db(csv_file, table)
        else:
            print(f"⚠️ No CSV found for table '{table}'")

# Example usage:
load_all_csvs("dummy_data_folder")
# Out:
# <class 'models.Company'>
# ⚠️ No CSV found for table '<class 'models.Company'>'
# <class 'models.Role'>
# ⚠️ No CSV found for table '<class 'models.Role'>'
# <class 'models.Address'>
# ⚠️ No CSV found for table '<class 'models.Address'>'
# <class 'models.UserCompanyRole'>
# ⚠️ No CSV found for table '<class 'models.UserCompanyRole'>'
# <class 'models.Department'>
# ⚠️ No CSV found for table '<class 'models.Department'>'
# <class 'models.Account'>
# ⚠️ No CSV found for table '<class 'models.Account'>'
# <class 'models.Customer'>
# ⚠️ No CSV found for table '<class 'models.Customer'>'
# <class 'models.Vendor'>
# ⚠️ No CSV found for table '<class 'models.Vendor'>'
# <class 'models.Product'>
# ⚠️ No CSV found for table '<class 'models.Product'>'
# <class 'models.CompanyGSTIN'>
# ⚠️ No CSV found for table '<class 'models.CompanyGSTIN'>'
# <class 'models.Transaction'>
# ⚠️ No CSV found for table '<class 'models.Transaction'>'
# <class 'models.Inventory'>
# ⚠️ No CSV found for table '<class 'models.Inventory'>'
# <class 'models.SalesOrder'>
# ⚠️ No CSV found for table '<class 'models.SalesOrder'>'
# <class 'models.PurchaseOrder'>
# ⚠️ No CSV found for table '<class 'models.PurchaseOrder'>'
# <class 'models.FixedAsset'>
# ⚠️ No CSV found for table '<class 'models.FixedAsset'>'
# <class 'models.Employee'>
# ⚠️ No CSV found for table '<class 'models.Employee'>'
# <class 'models.SalesOrderItem'>
# ⚠️ No CSV found for table '<class 'models.SalesOrderItem'>'
# <class 'models.PurchaseOrderItem'>
# ⚠️ No CSV found for table '<class 'models.PurchaseOrderItem'>'
# <class 'models.Invoice'>
# ⚠️ No CSV found for table '<class 'models.Invoice'>'
# <class 'models.Payable'>
# ⚠️ No CSV found for table '<class 'models.Payable'>'
# <class 'models.Payroll'>
# ⚠️ No CSV found for table '<class 'models.Payroll'>'
# <class 'models.AuditLog'>
# ⚠️ No CSV found for table '<class 'models.AuditLog'>'
# <class 'models.Subscription'>
# ⚠️ No CSV found for table '<class 'models.Subscription'>'
# <class 'models.Payment'>
# ⚠️ No CSV found for table '<class 'models.Payment'>'
# <class 'models.EmailVerification'>
# ⚠️ No CSV found for table '<class 'models.EmailVerification'>'
# <class 'models.PhoneVerification'>
# ⚠️ No CSV found for table '<class 'models.PhoneVerification'>'
# <class 'models.FileExport'>
# ⚠️ No CSV found for table '<class 'models.FileExport'>'

# %%
from sqlalchemy.orm import Session
import pandas as pd

def load_all_csvs_with_orm(engine, csv_folder):
    session = Session(engine)

    table_models = get_tables_in_order()  # e.g., [Company, Employee, Department]

    for model_class in table_models:
        table_name = model_class.__tablename__  # ORM table name
        print(table_name)
        csv_file = f"{csv_folder}/{table_name}.csv"

        df = pd.read_csv(csv_file)

        # Convert each row into ORM objects
        records = [model_class(**row.to_dict()) for _, row in df.iterrows()]

        # Add to DB
        session.add_all(records)
        session.commit()

    session.close()

# %%
engine = create_engine(DATABASE_URL)
folder_name = "dummy_data_full"

load_all_csvs_with_orm(engine, folder_name)
# Out:
# companies
# ---------------------------------------------------------------------------
# StringDataRightTruncation                 Traceback (most recent call last)
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2114, in Connection._exec_insertmany_context(self, dialect, context)
#    2113     else:
# -> 2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# StringDataRightTruncation: value too long for type character varying(10)
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 engine = create_engine(DATABASE_URL)
#       2 folder_name = "dummy_data_full"
# ----> 4 load_all_csvs_with_orm(engine, folder_name)
#
# Cell In[7], line 21, in load_all_csvs_with_orm(engine, csv_folder)
#      19     # Add to DB
#      20     session.add_all(records)
# ---> 21     session.commit()
#      23 session.close()
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2032, in Session.commit(self)
#    2029 if trans is None:
#    2030     trans = self._autobegin_t()
# -> 2032 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1313, in SessionTransaction.commit(self, _to_root)
#    1311 if self._state is not SessionTransactionState.PREPARED:
#    1312     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1313         self._prepare_impl()
#    1315 if self._parent is None or self.nested:
#    1316     for conn, trans, should_commit, autoclose in set(
#    1317         self._connections.values()
#    1318     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1288, in SessionTransaction._prepare_impl(self)
#    1286     if self.session._is_clean():
#    1287         break
# -> 1288     self.session.flush()
#    1289 else:
#    1290     raise exc.FlushError(
#    1291         "Over 100 subsequent flushes have occurred within "
#    1292         "session.commit() - is an after_flush() hook "
#    1293         "creating new objects?"
#    1294     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4345, in Session.flush(self, objects)
#    4343 try:
#    4344     self._flushing = True
# -> 4345     self._flush(objects)
#    4346 finally:
#    4347     self._flushing = False
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4480, in Session._flush(self, objects)
#    4477     transaction.commit()
#    4479 except:
# -> 4480     with util.safe_reraise():
#    4481         transaction.rollback(_capture_exception=True)
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4441, in Session._flush(self, objects)
#    4439 self._warn_on_events = True
#    4440 try:
# -> 4441     flush_context.execute()
#    4442 finally:
#    4443     self._warn_on_events = False
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)     90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)    119     ),
#     120 )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:1048, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1045 records = list(records)
#    1046 multiparams = [rec[2] for rec in records]
# -> 1048 result = connection.execute(
#    1049     statement, multiparams, execution_options=execution_options
#    1050 )
#    1051 if bookkeeping:
#    1052     for (
#    1053         (
#    1054             state,
#    (...)   1063         last_inserted_params,
#    1064     ) in zip(records, result.context.compiled_parameters):
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1413     raise exc.ObjectNotExecutableError(statement) from err
#    1414 else:
# -> 1415     return meth(
#    1416         self,
#    1417         distilled_parameters,
#    1418         execution_options or NO_OPTIONS,
#    1419     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1637, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1626     "compiled_cache", self.engine._compiled_cache
#    1627 )
#    1629 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1630     dialect=dialect,
#    1631     compiled_cache=compiled_cache,
#    (...)   1635     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636 )
# -> 1637 ret = self._execute_context(
#    1638     dialect,
#    1639     dialect.execution_ctx_cls._init_compiled,
#    1640     compiled_sql,
#    1641     distilled_parameters,
#    1642     execution_options,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     elem,
#    1646     extracted_params,
#    1647     cache_hit=cache_hit,
#    1648 )
#    1649 if has_events:
#    1650     self.dispatch.after_execute(
#    1651         self,
#    1652         elem,
#    (...)   1656         ret,
#    1657     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1840, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837 context.pre_exec()
#    1839 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1840     return self._exec_insertmany_context(dialect, context)
#    1841 else:
#    1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2122, in Connection._exec_insertmany_context(self, dialect, context)
#    2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
# -> 2122     self._handle_dbapi_exception(
#    2123         e,
#    2124         sql_util._long_statement(sub_stmt),
#    2125         sub_params,
#    2126         cursor,
#    2127         context,
#    2128         is_sub_exec=True,
#    2129     )
#    2131 if engine_events:
#    2132     self.dispatch.after_cursor_execute(
#    2133         self,
#    2134         cursor,
#    (...)   2138         context.executemany,
#    2139     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2351, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2349 elif should_wrap:
#    2350     assert sqlalchemy_exception is not None
# -> 2351     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2352 else:
#    2353     assert exc_info[1] is not None
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2114, in Connection._exec_insertmany_context(self, dialect, context)
#    2112             break
#    2113     else:
# -> 2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
#    2122     self._handle_dbapi_exception(
#    2123         e,
#    2124         sql_util._long_statement(sub_stmt),
#    (...)   2128         is_sub_exec=True,
#    2129     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# DataError: (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(10)
#
# [SQL: INSERT INTO companies (company_id, name, cin, pan, created_at) VALUES (%(company_id__0)s::UUID, %(name__0)s, %(cin__0)s, %(pan__0)s, %(created_at__0)s), (%(company_id__1)s::UUID, %(name__1)s, %(cin__1)s, %(pan__1)s, %(created_at__1)s), (%(company_id_ ... 4068 characters truncated ... ed_at__48)s), (%(company_id__49)s::UUID, %(name__49)s, %(cin__49)s, %(pan__49)s, %(created_at__49)s)]
# [parameters: {'pan__0': 'Gw003569302', 'name__0': 'Peter Bullock', 'cin__0': 'iB492209632', 'created_at__0': '2023-04-12 11:51:52', 'company_id__0': '5f84b9d2-ea42-4b8f-ba29-a080f089a87e', 'pan__1': 'IV863708620', 'name__1': 'Karen Mccoy', 'cin__1': 'DB656636176', 'created_at__1': '2023-04-15 07:27:16', 'company_id__1': '8c7f0b27-6c32-4530-9d32-e6c04875d130', 'pan__2': 'Zi551607267', 'name__2': 'Nicholas Hughes', 'cin__2': 'sH794278115', 'created_at__2': '2023-12-14 04:11:27', 'company_id__2': '7c1ed19d-c166-48da-9ad5-5089765fb5bd', 'pan__3': 'Vo633925508', 'name__3': 'Michael Lane', 'cin__3': 'Cm765034913', 'created_at__3': '2023-05-13 14:16:05', 'company_id__3': '6577a689-6b05-40ce-ba00-ae14f63d4a5c', 'pan__4': 'ux622984320', 'name__4': 'Christopher Clements', 'cin__4': 'rh078875102', 'created_at__4': '2022-11-08 10:15:16', 'company_id__4': 'e6e7feaa-8de8-44a3-a959-718a50704464', 'pan__5': 'rL414624650', 'name__5': 'Pamela May', 'cin__5': 'CF494082081', 'created_at__5': '2023-10-18 02:08:20', 'company_id__5': 'daa06ec3-6ba1-4463-bea9-d23eb9fe5b9f', 'pan__6': 'YZ287295836', 'name__6': 'Steven Leon', 'cin__6': 'ns917592064', 'created_at__6': '2025-03-02 19:03:51', 'company_id__6': 'e7db09f0-5b39-4d30-9fda-499b5bb3ec78', 'pan__7': 'OM511515519', 'name__7': 'Tracy Johnson', 'cin__7': 'yv032677302', 'created_at__7': '2024-06-27 12:56:10', 'company_id__7': 'fda8041e-2a05-4c17-b70c-6be0f0180b05', 'pan__8': 'SS632032103', 'name__8': 'Erin Diaz', 'cin__8': 'bB311390592', 'created_at__8': '2022-10-23 12:02:43', 'company_id__8': '0b82e5c2-786f-40c5-9343-615a0c1b73cc', 'pan__9': 'Jl182441650', 'name__9': 'Rachel Pruitt', 'cin__9': 'am411724725', 'created_at__9': '2024-09-22 08:00:58', 'company_id__9': '474f07c5-fdba-47fc-92aa-102a9d943e15' ... 150 parameters truncated ... 'pan__40': 'TZ639566783', 'name__40': 'Megan Jackson', 'cin__40': 'Wo047954831', 'created_at__40': '2022-10-24 14:19:39', 'company_id__40': '202fccc4-482b-454c-8ecf-ab203899cd5d', 'pan__41': 'og258423909', 'name__41': 'Melissa Campos', 'cin__41': 'ZA135364496', 'created_at__41': '2024-06-13 23:13:57', 'company_id__41': 'cad7a80d-6ef5-4669-aaa9-3a47f44085b6', 'pan__42': 'uC614721012', 'name__42': 'Bryce Hubbard', 'cin__42': 'sn114122801', 'created_at__42': '2024-01-25 23:44:12', 'company_id__42': '6cbd2803-83eb-4b04-ace8-ac4d5672e19c', 'pan__43': 'TN106908348', 'name__43': 'John Barajas', 'cin__43': 'ln268400233', 'created_at__43': '2024-09-14 20:50:42', 'company_id__43': 'eb1abbba-cf12-42ed-b25e-26ad6cb78a67', 'pan__44': 'Xa447902938', 'name__44': 'Martin Lindsey', 'cin__44': 'sV668442631', 'created_at__44': '2023-08-22 15:09:58', 'company_id__44': 'f1f3aa1e-094d-4e20-8e75-a202d517ddcb', 'pan__45': 'Wo057463930', 'name__45': 'Nicole Hartman', 'cin__45': 'fx119585255', 'created_at__45': '2023-06-05 06:21:49', 'company_id__45': '861c2f76-534f-4beb-b06e-a51ea1bc01a9', 'pan__46': 'kV752568880', 'name__46': 'John Lucas', 'cin__46': 'CR841694020', 'created_at__46': '2023-03-23 19:02:37', 'company_id__46': '052e5d30-c019-4d94-bb63-5b04317841ed', 'pan__47': 'UR348135176', 'name__47': 'Bryan Casey', 'cin__47': 'EB954638846', 'created_at__47': '2024-12-12 01:30:19', 'company_id__47': '7834abd7-a989-4031-9cec-974bb24e101b', 'pan__48': 'Ti108380931', 'name__48': 'Rhonda Mathis', 'cin__48': 'wB218704830', 'created_at__48': '2023-01-28 08:34:20', 'company_id__48': '4f12c98b-2fe9-45c2-b71c-08b378181569', 'pan__49': 'pR124577960', 'name__49': 'Crystal Ross', 'cin__49': 'FB521083536', 'created_at__49': '2024-09-03 11:05:54', 'company_id__49': '06c9e5e3-f1ad-4149-9b96-102ee7afb04e'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
# ---------- Database Setup ----------
DATABASE_URL = "postgresql+psycopg2://postgres:ashish6677@34.30.63.17:5432/postgres"
engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)
session = Session()

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, inspect
from sqlalchemy.orm import sessionmaker
from models import Base, Company, Employee  # Import your ORM models
from models import get_tables_in_order  # Function returning ORM classes
from sqlalchemy.exc import DataError
from sqlalchemy.dialects.postgresql import insert as pg_insert

# DB connection

engine = create_engine(DATABASE_URL)


inspector = inspect(engine)




def bulk_insert_ignore_conflicts(session, records, model_class):
    table = model_class.__table__
    values = [obj.__dict__.copy() for obj in records]
    # Remove SQLAlchemy state key if present
    for v in values:
        v.pop('_sa_instance_state', None)
    stmt = pg_insert(table).values(values)
    stmt = stmt.on_conflict_do_nothing(index_elements=['company_id'])
    session.execute(stmt)
    session.commit()


def clean_dataframe_for_orm(df, table_name):
    """Truncate strings in DF according to DB column sizes"""
    columns_info = inspector.get_columns(table_name)
    for col in columns_info:
        col_name = col["name"]
        col_type = str(col["type"])
        print(f"col name and type: {col_name} & {col_type}")
        if "VARCHAR" in col_type:
            max_len = int(col_type.split("(")[1].split(")")[0])
            print(max_len)
            if col_name in df.columns:
                df[col_name] = df[col_name].astype(str)
                df[col_name] = df[col_name].apply(lambda x: x[:max_len])
                print(df[col_name].loc[:])
                print(df[col_name].shape)

        elif "character" in col_type and "varying" not in col_type:
            max_len = int(col_type.split("(")[1].split(")")[0])
            print(max_len)
            if col_name in df.columns:
                df[col_name] = df[col_name].astype(str).str.slice(0, max_len)

    return df





# Path to CSV folder
folder_name = "dummy_data_full"

# Loop through ORM models in correct order
for model_class in get_tables_in_order():
    table_name = model_class.__tablename__
    print(table_name)
    csv_file = os.path.join(folder_name, f"{table_name}.csv")
    
    if os.path.exists(csv_file):
        df = pd.read_csv(csv_file)

        # Clean based on DB schema
        df = clean_dataframe_for_orm(df, table_name)

        # Convert to ORM objects
        records = [model_class(**row.to_dict()) for _, row in df.iterrows()]

        # Insert into DB
        try:
            if table_name == "companies":
                bulk_insert_ignore_conflicts(session, records, model_class)  # 👈 Use your new function
            else:
                session.bulk_save_objects(records)  # others unchanged
                session.commit()
        except DataError as e:
            session.rollback()
            print(f"❌ Data too long for {table_name}: {e}")


# Commit changes
session.commit()
session.close()
# Out:
# companies
# col name and type: company_id & UUID
# col name and type: name & VARCHAR(255)
# 255
# 0            Peter Bullock
# 1              Karen Mccoy
# 2          Nicholas Hughes
# 3             Michael Lane
# 4     Christopher Clements
# 5               Pamela May
# 6              Steven Leon
# 7            Tracy Johnson
# 8                Erin Diaz
# 9            Rachel Pruitt
# 10    Dr. Ethan Jordan DVM
# 11             Sarah Flynn
# 12          Jessica Bailey
# 13             Tammy Jones
# 14            Joseph Lopez
# 15              Amy Dorsey
# 16          Jason Sullivan
# 17           Paul Sullivan
# 18        Michael Mckinney
# 19         Benjamin Parker
# 20           Courtney Bush
# 21           Scott Walters
# 22             Holly Avila
# 23          Crystal Cortez
# 24           Timothy Brown
# 25            Judith Jones
# 26            Zoe Anderson
# 27    Kristopher Hernandez
# 28             Gerald Tran
# 29            Matthew Hart
# 30           Craig Morales
# 31          Erica Marshall
# 32          Breanna Ibarra
# 33             Robin Hicks
# 34            Dennis Floyd
# 35            Jamie Nelson
# 36             Laura Hodge
# 37              Lori Weber
# 38           Gerald Baxter
# 39              Ann Haynes
# 40           Megan Jackson
# 41          Melissa Campos
# 42           Bryce Hubbard
# 43            John Barajas
# 44          Martin Lindsey
# 45          Nicole Hartman
# 46              John Lucas
# 47             Bryan Casey
# 48           Rhonda Mathis
# 49            Crystal Ross
# Name: name, dtype: object
# (50,)
# col name and type: cin & VARCHAR(21)
# 21
# 0     iB492209632
# 1     DB656636176
# 2     sH794278115
# 3     Cm765034913
# 4     rh078875102
# 5     CF494082081
# 6     ns917592064
# 7     yv032677302
# 8     bB311390592
# 9     am411724725
# 10    bd926930150
# 11    Yi405687155
# 12    jX600086902
# 13    Ah550578934
# 14    Wl923579049
# 15    nQ336316327
# 16    aM702145892
# 17    zt683114473
# 18    lj429483698
# 19    BB891089629
# 20    KZ439758365
# 21    kc802559039
# 22    Gh176962838
# 23    lR851187649
# 24    SM093998839
# 25    lc440935319
# 26    yr140748423
# 27    xD042312600
# 28    Fq991390207
# 29    ym394764411
# 30    YM922484425
# 31    ak514168767
# 32    Jb730861701
# 33    Zd400934976
# 34    RN331911600
# 35    wK528916616
# 36    lL658275476
# 37    ib774746257
# 38    Yo440305849
# 39    mj437948653
# 40    Wo047954831
# 41    ZA135364496
# 42    sn114122801
# 43    ln268400233
# 44    sV668442631
# 45    fx119585255
# 46    CR841694020
# 47    EB954638846
# 48    wB218704830
# 49    FB521083536
# Name: cin, dtype: object
# (50,)
# col name and type: pan & VARCHAR(10)
# 10
# 0     Gw00356930
# 1     IV86370862
# 2     Zi55160726
# 3     Vo63392550
# 4     ux62298432
# 5     rL41462465
# 6     YZ28729583
# 7     OM51151551
# 8     SS63203210
# 9     Jl18244165
# 10    gz87891459
# 11    QP18723263
# 12    gG42872161
# 13    nR14848754
# 14    Kv18960736
# 15    In58811892
# 16    ub27527658
# 17    WZ47197013
# 18    ho03258858
# 19    KT70099112
# 20    oC44374951
# 21    Qy47336529
# 22    io36319604
# 23    yV10352845
# 24    Vr61346749
# 25    nX61179573
# 26    vo41067723
# 27    SW04879342
# 28    rg82371560
# 29    Di05845165
# 30    fL87520574
# 31    qx13514764
# 32    DS19062648
# 33    cT96518277
# 34    gg14240194
# 35    oy62526639
# 36    sz84629191
# 37    NT22418595
# 38    lm99034592
# 39    Cu73392484
# 40    TZ63956678
# 41    og25842390
# 42    uC61472101
# 43    TN10690834
# 44    Xa44790293
# 45    Wo05746393
# 46    kV75256888
# 47    UR34813517
# 48    Ti10838093
# 49    pR12457796
# Name: pan, dtype: object
# (50,)
# col name and type: created_at & TIMESTAMP
# C:\Users\user\AppData\Local\Temp\ipykernel_15892\3968165433.py:76: SAWarning: relationship 'Account.children' will copy column accounts.account_id to column accounts.parent_account_id, which conflicts with relationship(s): 'Account.parent' (copies accounts.account_id to accounts.parent_account_id). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   To silence this warning, add the parameter 'overlaps="parent"' to the 'Account.children' relationship. (Background on this warning at: https://sqlalche.me/e/20/qzyx) (This warning originated from the `configure_mappers()` process, which was invoked automatically in response to a user-initiated operation.)
#   records = [model_class(**row.to_dict()) for _, row in df.iterrows()]
# roles
# col name and type: role_id & UUID
# col name and type: company_id & UUID
# col name and type: role_name & VARCHAR(50)
# 50
# 0      Mrs. Michelle Fisher
# 1           Timothy Simmons
# 2              James Carter
# 3                Keith Wong
# 4              Ashley Grant
# 5         Thomas Stephenson
# 6          Nicholas Jenkins
# 7               Faith Mckay
# 8              Theresa West
# 9         Michelle Martinez
# 10             Nicole Woods
# 11         Alexander Nguyen
# 12    Mitchell Mcdonald DVM
# 13           Autumn Winters
# 14               Gary Brown
# 15              Kelly Beard
# 16           Leslie Edwards
# 17                Kyle Owen
# 18               Anna Davis
# 19             Leah Barrett
# 20             Tiffany Webb
# 21                Eric Gray
# 22              Mary Romero
# 23            Melissa Myers
# 24            Manuel Duncan
# 25             Dawn Perkins
# 26            Bryan Stevens
# 27           Shannon Palmer
# 28            James Osborne
# 29           Allison Wilson
# 30                 Eric Lee
# 31             Bryce Oliver
# 32              Scott Evans
# 33         Jordan Gillespie
# 34           Valerie Martin
# 35              John Snyder
# 36           Bryan Marshall
# 37           Dennis Johnson
# 38          Carly Donaldson
# 39           Molly Boyle MD
# 40           Diamond Ramsey
# 41            Sandra Chavez
# 42            Colleen Burke
# 43           Karen Chung MD
# 44           Jennifer Scott
# 45             Logan Rivera
# 46             Sara Stevens
# 47           Sharon Goodman
# 48             Christie Fry
# 49               Brad Woods
# Name: role_name, dtype: object
# (50,)
# col name and type: description & TEXT
# col name and type: created_at & TIMESTAMP
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2114, in Connection._exec_insertmany_context(self, dialect, context)
#    2113     else:
# -> 2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "roles_pkey"
# DETAIL:  Key (role_id)=(0200bc30-2086-414d-afb0-456f4bcfb067) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[3], line 83
#      81         bulk_insert_ignore_conflicts(session, records, model_class)  # 👈 Use your new function
#      82     else:
# ---> 83         session.bulk_save_objects(records)  # others unchanged
#      84         session.commit()
#      85 except DataError as e:
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4578, in Session.bulk_save_objects(self, objects, return_defaults, update_changed_only, preserve_order)
#    4573     return (state.mapper, state.key is not None)
#    4575 for (mapper, isupdate), states in itertools.groupby(
#    4576     obj_states, grouping_key
#    4577 ):
# -> 4578     self._bulk_save_mappings(
#    4579         mapper,
#    4580         states,
#    4581         isupdate=isupdate,
#    4582         isstates=True,
#    4583         return_defaults=return_defaults,
#    4584         update_changed_only=update_changed_only,
#    4585         render_nulls=False,
#    4586     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4755, in Session._bulk_save_mappings(self, mapper, mappings, isupdate, isstates, return_defaults, update_changed_only, render_nulls)
#    4752     transaction.commit()
#    4754 except:
# -> 4755     with util.safe_reraise():
#    4756         transaction.rollback(_capture_exception=True)
#    4757 finally:
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\session.py:4744, in Session._bulk_save_mappings(self, mapper, mappings, isupdate, isstates, return_defaults, update_changed_only, render_nulls)
#    4736         bulk_persistence._bulk_update(
#    4737             mapper,
#    4738             mappings,
#    (...)   4741             update_changed_only=update_changed_only,
#    4742         )
#    4743     else:
# -> 4744         bulk_persistence._bulk_insert(
#    4745             mapper,
#    4746             mappings,
#    4747             transaction,
#    4748             isstates=isstates,
#    4749             return_defaults=return_defaults,
#    4750             render_nulls=render_nulls,
#    4751         )
#    4752     transaction.commit()
#    4754 except:
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:222, in _bulk_insert(mapper, mappings, session_transaction, isstates, return_defaults, render_nulls, use_orm_insert_stmt, execution_options)
#     182 extra_bp_names = (
#     183     [
#     184         b.key
#    (...)    189     else ()
#     190 )
#     192 records = (
#     193     (
#     194         None,
#    (...)    219     )
#     220 )
# --> 222 result = persistence._emit_insert_statements(
#     223     base_mapper,
#     224     None,
#     225     super_mapper,
#     226     table,
#     227     records,
#     228     bookkeeping=bookkeeping,
#     229     use_orm_insert_stmt=use_orm_insert_stmt,
#     230     execution_options=execution_options,
#     231 )
#     232 if use_orm_insert_stmt is not None:
#     233     if not use_orm_insert_stmt._returning or return_result is None:
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:1048, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1045 records = list(records)
#    1046 multiparams = [rec[2] for rec in records]
# -> 1048 result = connection.execute(
#    1049     statement, multiparams, execution_options=execution_options
#    1050 )
#    1051 if bookkeeping:
#    1052     for (
#    1053         (
#    1054             state,
#    (...)   1063         last_inserted_params,
#    1064     ) in zip(records, result.context.compiled_parameters):
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1413     raise exc.ObjectNotExecutableError(statement) from err
#    1414 else:
# -> 1415     return meth(
#    1416         self,
#    1417         distilled_parameters,
#    1418         execution_options or NO_OPTIONS,
#    1419     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1637, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1626     "compiled_cache", self.engine._compiled_cache
#    1627 )
#    1629 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1630     dialect=dialect,
#    1631     compiled_cache=compiled_cache,
#    (...)   1635     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636 )
# -> 1637 ret = self._execute_context(
#    1638     dialect,
#    1639     dialect.execution_ctx_cls._init_compiled,
#    1640     compiled_sql,
#    1641     distilled_parameters,
#    1642     execution_options,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     elem,
#    1646     extracted_params,
#    1647     cache_hit=cache_hit,
#    1648 )
#    1649 if has_events:
#    1650     self.dispatch.after_execute(
#    1651         self,
#    1652         elem,
#    (...)   1656         ret,
#    1657     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1840, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837 context.pre_exec()
#    1839 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1840     return self._exec_insertmany_context(dialect, context)
#    1841 else:
#    1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2122, in Connection._exec_insertmany_context(self, dialect, context)
#    2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
# -> 2122     self._handle_dbapi_exception(
#    2123         e,
#    2124         sql_util._long_statement(sub_stmt),
#    2125         sub_params,
#    2126         cursor,
#    2127         context,
#    2128         is_sub_exec=True,
#    2129     )
#    2131 if engine_events:
#    2132     self.dispatch.after_cursor_execute(
#    2133         self,
#    2134         cursor,
#    (...)   2138         context.executemany,
#    2139     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2351, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2349 elif should_wrap:
#    2350     assert sqlalchemy_exception is not None
# -> 2351     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2352 else:
#    2353     assert exc_info[1] is not None
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2114, in Connection._exec_insertmany_context(self, dialect, context)
#    2112             break
#    2113     else:
# -> 2114         dialect.do_execute(
#    2115             cursor,
#    2116             sub_stmt,
#    2117             sub_params,
#    2118             context,
#    2119         )
#    2121 except BaseException as e:
#    2122     self._handle_dbapi_exception(
#    2123         e,
#    2124         sql_util._long_statement(sub_stmt),
#    (...)   2128         is_sub_exec=True,
#    2129     )
#
# File c:\Users\user\Desktop\Github_repo\langchain-NL-to-SQL-project\.venv\Lib\site-packages\sqlalchemy\engine\default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "roles_pkey"
# DETAIL:  Key (role_id)=(0200bc30-2086-414d-afb0-456f4bcfb067) already exists.
#
# [SQL: INSERT INTO roles (role_id, company_id, role_name, description, created_at) VALUES (%(role_id__0)s::UUID, %(company_id__0)s::UUID, %(role_name__0)s, %(description__0)s, %(created_at__0)s), (%(role_id__1)s::UUID, %(company_id__1)s::UUID, %(role_name__ ... 5231 characters truncated ... d__49)s::UUID, %(company_id__49)s::UUID, %(role_name__49)s, %(description__49)s, %(created_at__49)s)]
# [parameters: {'description__0': 'Federal information bill box member base. Ahead activity simply officer owner question.', 'company_id__0': '74acb795-400f-4f4f-bc9f-6d49beb1469f', 'role_name__0': 'Mrs. Michelle Fisher', 'role_id__0': '0200bc30-2086-414d-afb0-456f4bcfb067', 'created_at__0': '2023-04-05 03:07:02', 'description__1': 'Trade parent opportunity bill remember.', 'company_id__1': 'b2099831-d995-46b8-9865-4ca93ccd46cf', 'role_name__1': 'Timothy Simmons', 'role_id__1': '626ef389-2343-4290-8906-126ef93910ee', 'created_at__1': '2023-10-04 07:39:45', 'description__2': 'Light article more fish.', 'company_id__2': 'b6e77aa3-54c1-4e5b-aa05-16ccdd7196f0', 'role_name__2': 'James Carter', 'role_id__2': '6702f9fc-bd13-4915-9860-2d407c2be977', 'created_at__2': '2023-09-08 10:09:25', 'description__3': 'Husband tonight simply center themselves enough.', 'company_id__3': '5621c24a-877c-415e-8725-6774ed8ce9e8', 'role_name__3': 'Keith Wong', 'role_id__3': '04fcfaf9-d787-4297-afa3-024ba6aa623b', 'created_at__3': '2024-03-21 10:45:43', 'description__4': 'Girl along themselves game interview speech today.', 'company_id__4': '06c9e5e3-f1ad-4149-9b96-102ee7afb04e', 'role_name__4': 'Ashley Grant', 'role_id__4': '531ca9d9-0da5-458e-be83-c7104358c181', 'created_at__4': '2023-06-30 23:39:43', 'description__5': 'Station resource body hope industry.', 'company_id__5': 'b6e77aa3-54c1-4e5b-aa05-16ccdd7196f0', 'role_name__5': 'Thomas Stephenson', 'role_id__5': '0e32673d-6359-447e-ba4e-a66e91dc3e9b', 'created_at__5': '2025-05-19 13:43:04', 'description__6': 'Which us run hard.', 'company_id__6': 'eb1abbba-cf12-42ed-b25e-26ad6cb78a67', 'role_name__6': 'Nicholas Jenkins', 'role_id__6': '4cd95d9f-06ea-4259-b17b-1240b3830826', 'created_at__6': '2023-03-02 05:41:50', 'description__7': 'Exist best officer.', 'company_id__7': '5621c24a-877c-415e-8725-6774ed8ce9e8', 'role_name__7': 'Faith Mckay', 'role_id__7': '210baedc-a95e-4346-8cd7-dc687597b3d8', 'created_at__7': '2024-01-19 20:57:58', 'description__8': 'Poor itself concern them either site of.', 'company_id__8': '474f07c5-fdba-47fc-92aa-102a9d943e15', 'role_name__8': 'Theresa West', 'role_id__8': '38e022c3-9adf-4d66-9d67-b57c48995f88', 'created_at__8': '2023-05-17 07:04:55', 'description__9': 'Meet day cover two. Old task husband education.', 'company_id__9': '6a53cd75-dab2-4fb6-acac-59e3c8a6713f', 'role_name__9': 'Michelle Martinez', 'role_id__9': 'a4a1f9d8-72f5-4b4e-b8b5-71ee30af6302', 'created_at__9': '2025-04-13 07:17:00' ... 150 parameters truncated ... 'description__40': 'Exist speak night check.', 'company_id__40': '4f12c98b-2fe9-45c2-b71c-08b378181569', 'role_name__40': 'Diamond Ramsey', 'role_id__40': '22556ae0-4fa1-4689-a5c4-501e7ed6fdb3', 'created_at__40': '2023-04-25 14:21:33', 'description__41': 'Floor star Republican finally drive across avoid.', 'company_id__41': '6237c655-0bee-40f7-a5d1-20fae3cbc54b', 'role_name__41': 'Sandra Chavez', 'role_id__41': '05f87f50-7f07-48ac-9331-b5a795cf610a', 'created_at__41': '2023-10-23 17:05:50', 'description__42': 'Relate above pass short know ever.', 'company_id__42': 'daa06ec3-6ba1-4463-bea9-d23eb9fe5b9f', 'role_name__42': 'Colleen Burke', 'role_id__42': '5b89f09d-8f0b-479a-b0ee-8e503ba96bb2', 'created_at__42': '2024-05-26 14:15:08', 'description__43': 'Police firm tend move north science customer.', 'company_id__43': '6237c655-0bee-40f7-a5d1-20fae3cbc54b', 'role_name__43': 'Karen Chung MD', 'role_id__43': '9f2396c9-5ee3-440a-a20e-b8f5bf928ba3', 'created_at__43': '2025-04-28 03:23:19', 'description__44': 'Wind assume talk between quite thus eight account. Final same despite cut foot practice.', 'company_id__44': '5621c24a-877c-415e-8725-6774ed8ce9e8', 'role_name__44': 'Jennifer Scott', 'role_id__44': 'ea3c9f51-d3df-49c4-8b56-b98132181a58', 'created_at__44': '2024-04-21 15:23:13', 'description__45': 'Card nature less possible upon despite story turn. Risk speak character cover close operation red.', 'company_id__45': 'abcdd24e-678f-432b-b550-739fc042a0c0 ...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
session.rollback()

# %%
for model_class in get_tables_in_order():
    table_name = model_class.__tablename__
    print(table_name)
# Out:
# companies
# roles
# addresses
# user_company_roles
# departments
# accounts
# customers
# vendors
# products
# company_gstins
# transactions
# inventory
# sales_orders
# purchase_orders
# fixed_assets
# employees
# sales_order_items
# purchase_order_items
# invoices
# payables
# payroll
# audit_logs
# subscriptions
# payments
# email_verifications
# phone_verifications
# file_exports

# %%
from sqlalchemy.dialects.postgresql import insert as pg_insert
from sqlalchemy.exc import DataError, IntegrityError

def get_primary_key_names(model_class):
    """Return a list of primary key column names for a model class."""
    return [key.name for key in model_class.__table__.primary_key.columns]

def bulk_insert_ignore_conflicts(session, records, model_class, pk_names):
    """Bulk insert records, skipping duplicates on the table's PK(s)."""
    table = model_class.__table__
    values = [obj.__dict__.copy() for obj in records]
    for v in values:
        v.pop('_sa_instance_state', None)
    stmt = pg_insert(table).values(values)
    stmt = stmt.on_conflict_do_nothing(index_elements=pk_names)
    session.execute(stmt)
    session.commit()

def table_has_data(session, model_class):
    """Check if table has any rows."""
    return session.query(model_class).first() is not None

# Set up session as before
Session = sessionmaker(bind=engine)
session = Session()

for model_class in get_tables_in_order():
    table_name = model_class.__tablename__
    print(f"\n--- Processing table: {table_name} ---")
    csv_file = os.path.join(folder_name, f"{table_name}.csv")
    
    if os.path.exists(csv_file):
        df = pd.read_csv(csv_file)
        df = clean_dataframe_for_orm(df, table_name)
        records = [model_class(**row.to_dict()) for _, row in df.iterrows()]
        
        pk_names = get_primary_key_names(model_class)
        if not pk_names:
            print(f"⚠️ Skipping {table_name}: no primary key found!")
            continue
        
        try:
            # Always do UPSERT (skip duplicates) for bulk inserts!
            bulk_insert_ignore_conflicts(session, records, model_class, pk_names)
            print(f"✅ Bulk insert complete for {table_name} (duplicates skipped)")
        except DataError as e:
            session.rollback()
            print(f"❌ Data too long for {table_name}: {e}")
        except IntegrityError as e:
            session.rollback()
            print(f"❌ Integrity error for {table_name}: {e}")
    else:
        print(f"⚠️ No CSV found for table '{table_name}'")

session.close()
# Out:
# --- Processing table: companies ---
# col name and type: company_id & UUID
# col name and type: name & VARCHAR(255)
# 255
# 0            Peter Bullock
# 1              Karen Mccoy
# 2          Nicholas Hughes
# 3             Michael Lane
# 4     Christopher Clements
# 5               Pamela May
# 6              Steven Leon
# 7            Tracy Johnson
# 8                Erin Diaz
# 9            Rachel Pruitt
# 10    Dr. Ethan Jordan DVM
# 11             Sarah Flynn
# 12          Jessica Bailey
# 13             Tammy Jones
# 14            Joseph Lopez
# 15              Amy Dorsey
# 16          Jason Sullivan
# 17           Paul Sullivan
# 18        Michael Mckinney
# 19         Benjamin Parker
# 20           Courtney Bush
# 21           Scott Walters
# 22             Holly Avila
# 23          Crystal Cortez
# 24           Timothy Brown
# 25            Judith Jones
# 26            Zoe Anderson
# 27    Kristopher Hernandez
# 28             Gerald Tran
# 29            Matthew Hart
# 30           Craig Morales
# 31          Erica Marshall
# 32          Breanna Ibarra
# 33             Robin Hicks
# 34            Dennis Floyd
# 35            Jamie Nelson
# 36             Laura Hodge
# 37              Lori Weber
# 38           Gerald Baxter
# 39              Ann Haynes
# 40           Megan Jackson
# 41          Melissa Campos
# 42           Bryce Hubbard
# 43            John Barajas
# 44          Martin Lindsey
# 45          Nicole Hartman
# 46              John Lucas
# 47             Bryan Casey
# 48           Rhonda Mathis
# 49            Crystal Ross
# Name: name, dtype: object
# (50,)
# col name and type: cin & VARCHAR(21)
# 21
# 0     iB492209632
# 1     DB656636176
# 2     sH794278115
# 3     Cm765034913
# 4     rh078875102
# 5     CF494082081
# 6     ns917592064
# 7     yv032677302
# 8     bB311390592
# 9     am411724725
# 10    bd926930150
# 11    Yi405687155
# 12    jX600086902
# 13    Ah550578934
# 14    Wl923579049
# 15    nQ336316327
# 16    aM702145892
# 17    zt683114473
# 18    lj429483698
# 19    BB891089629
# 20    KZ439758365
# 21    kc802559039
# 22    Gh176962838
# 23    lR851187649
# 24    SM093998839
# 25    lc440935319
# 26    yr140748423
# 27    xD042312600
# 28    Fq991390207
# 29    ym394764411
# 30    YM922484425
# 31    ak514168767
# 32    Jb730861701
# 33    Zd400934976
# 34    RN331911600
# 35    wK528916616
# 36    lL658275476
# 37    ib774746257
# 38    Yo440305849
# 39    mj437948653
# 40    Wo047954831
# 41    ZA135364496
# 42    sn114122801
# 43    ln268400233
# 44    sV668442631
# 45    fx119585255
# 46    CR841694020
# 47    EB954638846
# 48    wB218704830
# 49    FB521083536
# Name: cin, dtype: object
# (50,)
# col name and type: pan & VARCHAR(10)
# 10
# 0     Gw00356930
# 1     IV86370862
# 2     Zi55160726
# 3     Vo63392550
# 4     ux62298432
# 5     rL41462465
# 6     YZ28729583
# 7     OM51151551
# 8     SS63203210
# 9     Jl18244165
# 10    gz87891459
# 11    QP18723263
# 12    gG42872161
# 13    nR14848754
# 14    Kv18960736
# 15    In58811892
# 16    ub27527658
# 17    WZ47197013
# 18    ho03258858
# 19    KT70099112
# 20    oC44374951
# 21    Qy47336529
# 22    io36319604
# 23    yV10352845
# 24    Vr61346749
# 25    nX61179573
# 26    vo41067723
# 27    SW04879342
# 28    rg82371560
# 29    Di05845165
# 30    fL87520574
# 31    qx13514764
# 32    DS19062648
# 33    cT96518277
# 34    gg14240194
# 35    oy62526639
# 36    sz84629191
# 37    NT22418595
# 38    lm99034592
# 39    Cu73392484
# 40    TZ63956678
# 41    og25842390
# 42    uC61472101
# 43    TN10690834
# 44    Xa44790293
# 45    Wo05746393
# 46    kV75256888
# 47    UR34813517
# 48    Ti10838093
# 49    pR12457796
# Name: pan, dtype: object
# (50,)
# col name and type: created_at & TIMESTAMP
# ✅ Bulk insert complete for companies (duplicates skipped)
#
# --- Processing table: roles ---
# col name and type: role_id & UUID
# col name and type: company_id & UUID
# col name and type: role_name & VARCHAR(50)
# 50
# 0      Mrs. Michelle Fisher
# 1           Timothy Simmons
# 2              James Carter
# 3                Keith Wong
# 4              Ashley Grant
# 5         Thomas Stephenson
# 6          Nicholas Jenkins
# 7               Faith Mckay
# 8              Theresa West
# 9         Michelle Martinez
# 10             Nicole Woods
# 11         Alexander Nguyen
# 12    Mitchell Mcdonald DVM
# 13           Autumn Winters
# 14               Gary Brown
# 15              Kelly Beard
# 16           Leslie Edwards
# 17                Kyle Owen
# 18               Anna Davis
# 19             Leah Barrett
# 20             Tiffany Webb
# 21                Eric Gray
# 22              Mary Romero
# 23            Melissa Myers
# 24            Manuel Duncan
# 25             Dawn Perkins
# 26            Bryan Stevens
# 27           Shannon Palmer
# 28            James Osborne
# 29           Allison Wilson
# 30                 Eric Lee
# 31             Bryce Oliver
# 32              Scott Evans
# 33         Jordan Gillespie
# 34           Valerie Martin
# 35              John Snyder
# 36           Bryan Marshall
# 37           Dennis Johnson
# 38          Carly Donaldson
# 39           Molly Boyle MD
# 40           Diamond Ramsey
# 41            Sandra Chavez
# 42            Colleen Burke
# 43           Karen Chung MD
# 44           Jennifer Scott
# 45             Logan Rivera
# 46             Sara Stevens
# 47           Sharon Goodman
# 48             Christie Fry
# 49               Brad Woods
# Name: role_name, dtype: object
# (50,)
# col name and type: description & TEXT
# col name and type: created_at & TIMESTAMP
# ✅ Bulk insert complete for roles (duplicates skipped)
#
# --- Processing table: addresses ---
# col name and type: address_id & UUID
# col name and type: company_id & UUID
# col name and type: address_line1 & VARCHAR(255)
# 255
# 0                 299 Lindsey Extensions
# 1              1529 Javier Road Apt. 459
# 2                      10508 Anne Course
# 3                      73851 Melvin Flat
# 4                  089 Richardson Center
# 5               7423 Mark Glens Apt. 679
# 6           18910 Joshua Bridge Apt. 617
# 7                       9447 Joshua Fall
# 8             684 Levine Lights Apt. 515
# 9     92413 Williams Crossroad Suite 023
# 10                    10268 Smith Island
# 11                  43220 Ricardo Drives
# 12                     3377 Cruz Estates
# 13                     3650 Sabrina Ford
# 14          098 Michael Circle Suite 448
# 15                      46328 Amy Rapids
# 16           1051 Robert Vista Suite 576
# 17            2590 Megan Summit Apt. 876
# 18                   53089 Michael Forks
# 19                    7711 Lawrence Loop
# 20            544 Roberts Parks Apt. 111
# 21                       2977 James Ramp
# 22                   914 Kimberly Street
# 23                     6571 Brendan Dale
# 24           90674 Sara Estate Suite 907
# 25                      88999 Larry Camp
# 26            01929 Keith Inlet Apt. 833
# 27           674 Matthew Fields Apt. 697
# 28             974 Patrick Road Apt. 546
# 29                      0632 Young Burgs
# 30                       179 Ruiz Street
# 31                  67442 Mahoney Courts
# 32             5163 Cody Brooks Apt. 986
# 33          938 Sanders Island Suite 659
# 34             218 Holmes Vista Apt. 057
# 35                     138 Jenkins Flats
# 36           54859 Smith Spurs Suite 723
# 37                28347 Alexandra Rapids
# 38          1162 Fisher Plains Suite 555
# 39                      6692 Anne Garden
# 40           18583 Rice Avenue Suite 552
# 41                   9632 Nathaniel Burg
# 42                     209 Johnson Trail
# 43                        414 Beth Ranch
# 44           50507 Castro Drive Apt. 956
# 45          86613 Thomas Brook Suite 969
# 46                   23835 Espinoza Port
# 47                      74999 Rose Green
# 48             6664 Kevin Vista Apt. 284
# 49       97559 Kristopher Park Suite 505
# Name: address_line1, dtype: object
# (50,)
# col name and type: address_line2 & VARCHAR(255)
# 255
# 0          58210 Wiggins Spur Apt. 516
# 1                   3577 Gonzalez Road
# 2          51076 Hunter Ville Apt. 982
# 3     759 Stephenson Parkways Apt. 240
# 4            2058 Karen Glens Apt. 067
# 5                  76672 Bryant Branch
# 6        6746 Clarke Causeway Apt. 706
# 7           113 Julian Forks Suite 286
# 8          719 Cooper Tunnel Suite 684
# 9                    23949 Julia Vista
# 10                    34516 John Locks
# 11           0945 Renee Ridge Apt. 847
# 12                 4700 Thompson Route
# 13                     3643 Erik Cliff
# 14               6333 Courtney Terrace
# 15             45439 Daniel Expressway
# 16                 399 Michael Gardens
# 17             491 Ford Place Apt. 608
# 18       3765 Parker Streets Suite 900
# 19             045 Bryan Isle Apt. 975
# 20            071 Irwin Field Apt. 343
# 21             94985 Anderson Mountain
# 22                  081 Tina Crossroad
# 23                    0321 King Hollow
# 24          956 Ashley Shoals Apt. 340
# 25                 05690 Graham Drives
# 26    08178 Vasquez Underpass Apt. 654
# 27                    17564 Hill Locks
# 28                 3574 Booker Orchard
# 29                 2449 Sherman Plains
# 30                  5598 Bryan Station
# 31                   633 Julie Circles
# 32      8837 Johnston Freeway Apt. 646
# 33                  0742 Erica Islands
# 34                   024 Morales Drive
# 35               23085 Hawkins Circles
# 36                    6178 Amber Union
# 37                  47720 Pamela Inlet
# 38           475 Tammy Ferry Suite 974
# 39                     386 Clark Trail
# 40     685 Harris Trafficway Suite 321
# 41              8693 Catherine Prairie
# 42                  50508 Tasha Greens
# 43                   920 Kathy Orchard
# 44            808 Rice Garden Apt. 804
# 45                  858 Campbell Brook
# 46                   365 Moore Orchard
# 47            072 Penny Glen Suite 230
# 48            700 Brown Mall Suite 590
# 49                  3200 Hannah Forges
# Name: address_line2, dtype: object
# (50,)
# col name and type: city & VARCHAR(100)
# 100
# 0              North Seth
# 1              Morganport
# 2              Lake Julie
# 3            Jeffreyhaven
# 4             Lake Ashley
# 5         West Danielview
# 6            Camachoburgh
# 7       Lake Victoriafort
# 8               East Lori
# 9         New Ashleyshire
# 10               Chadland
# 11           Russellmouth
# 12        North Meganport
# 13            West Alexis
# 14             West Amber
# 15            West Lauren
# 16            Ramirezstad
# 17             West David
# 18            Gregoryside
# 19          North Lindsey
# 20            East Marcus
# 21         New Andreaberg
# 22         East Scottberg
# 23              Odommouth
# 24        South Elizabeth
# 25              Brownfurt
# 26            Parkerville
# 27          Lawrenceburgh
# 28             Floresport
# 29           Crystalmouth
# 30         North Erictown
# 31            Robertshire
# 32    Port Catherinemouth
# 33          Campbellmouth
# 34       Christopherville
# 35           New Sarafurt
# 36          Levinechester
# 37        West Josephfurt
# 38          New Davidberg
# 39       West Nicoleshire
# 40         West Lucasbury
# 41       Port Deborahside
# 42         East Stephanie
# 43           East Gregory
# 44           West Anthony
# 45          South Theresa
# 46           Mccarthyberg
# 47             Port Karen
# 48         Port Rachelton
# 49              Smithside
# Name: city, dtype: object
# (50,)
# col name and type: state & VARCHAR(100)
# 100
# 0             Nevada
# 1           Maryland
# 2            Arizona
# 3              Maine
# 4             Hawaii
# 5         Washington
# 6         California
# 7               Ohio
# 8         New Mexico
# 9           Nebraska
# 10        New Mexico
# 11        Washington
# 12      Rhode Island
# 13           Florida
# 14          Kentucky
# 15     West Virginia
# 16    North Carolina
# 17           Arizona
# 18           Indiana
# 19            Oregon
# 20          Colorado
# 21    South Carolina
# 22          Kentucky
# 23    South Carolina
# 24           Wyoming
# 25         Tennessee
# 26         Tennessee
# 27     West Virginia
# 28          New York
# 29            Oregon
# 30          Arkansas
# 31            Oregon
# 32          Maryland
# 33              Ohio
# 34           Arizona
# 35       Mississippi
# 36              Utah
# 37            Nevada
# 38      South Dakota
# 39         Wisconsin
# 40         Tennessee
# 41          Delaware
# 42             Maine
# 43    South Carolina
# 44             Texas
# 45             Maine
# 46         Louisiana
# 47     New Hampshire
# 48          Nebraska
# 49            Hawaii
# Name: state, dtype: object
# (50,)
# col name and type: country & VARCHAR(100)
# 100
# 0                       Estonia
# 1                      Botswana
# 2                       Bermuda
# 3                      Malaysia
# 4         Palestinian Territory
# 5        British Virgin Islands
# 6                   Isle of Man
# 7                        Jordan
# 8                 Guinea-Bissau
# 9                       Romania
# 10                      Myanmar
# 11                New Caledonia
# 12                        Spain
# 13              Kyrgyz Republic
# 14                     Slovenia
# 15                      Moldova
# 16                      Denmark
# 17                  Afghanistan
# 18                  Puerto Rico
# 19                      Lesotho
# 20                      Uruguay
# 21                 South Africa
# 22                       Jordan
# 23                     Colombia
# 24        Saint Kitts and Nevis
# 25                      Georgia
# 26                        Sudan
# 27                        Chile
# 28     United States of America
# 29                        Aruba
# 30                  Isle of Man
# 31                      Bahrain
# 32         Netherlands Antilles
# 33    Saint Pierre and Miquelon
# 34                     Cameroon
# 35      Cocos (Keeling) Islands
# 36                      Iceland
# 37                        Gabon
# 38                  Isle of Man
# 39              Solomon Islands
# 40                        Korea
# 41          Antigua and Barbuda
# 42                      Denmark
# 43                         Chad
# 44                      Namibia
# 45                      Comoros
# 46                       Guyana
# 47                      Grenada
# 48      Cocos (Keeling) Islands
# 49                   Martinique
# Name: country, dtype: object
# (50,)
# col name and type: pin_code & VARCHAR(10)
# 10
# 0     73895
# 1     97384
# 2     85502
# 3     22692
# 4     25741
# 5     76313
# 6     20633
# 7     94755
# 8     92377
# 9     34722
# 10    18506
# 11    24304
# 12    28962
# 13     8019
# 14    95485
# 15    20165
# 16    30852
# 17    78038
# 18    42416
# 19    53746
# 20    70025
# 21    24435
# 22     5001
# 23    17591
# 24    80544
# 25    21982
# 26    41478
# 27    83125
# 28    25253
# 29    13944
# 30    97950
# 31    65743
# 32    38444
# 33    60393
# 34    54903
# 35    74820
# 36    19259
# 37    73775
# 38    53032
# 39    67095
# 40    22790
# 41    63034
# 42    19734
# 43    39005
# 44    38113
# 45    31311
# 46    80352
# 47    80120
# 48    31352
# 49    71311
# Name: pin_code, dtype: object
# (50,)
# col name and type: latitude & DOUBLE PRECISION
# col name and type: longitude & DOUBLE PRECISION
# col name and type: created_at & TIMESTAMP
# col name and type: updated_at & TIMESTAMP
# ✅ Bulk insert complete for addresses (duplicates skipped)
#
# --- Processing table: user_company_roles ---
# col name and type: erp_user_id & UUID
# col name and type: company_id & UUID
# col name and type: role_id & UUID
# col name and type: created_at & TIMESTAMP
# col name and type: updated_at & TIMESTAMP
# ✅ Bulk insert complete for user_company_roles (duplicates skipped)
#
# --- Processing table: departments ---
# col name and type: department_id & UUID
# col name and type: company_id & UUID
# col name and type: name & VARCHAR(100)
# 100
# 0           Kim Sullivan
# 1         Diamond Daniel
# 2     Christopher Dunlap
# 3          Michael Davis
# 4            Holly Scott
# 5          Rodney Foster
# 6       Joshua Klein Jr.
# 7         Mathew Elliott
# 8          Terry Hensley
# 9         Barbara Garcia
# 10      Michelle Goodman
# 11      Matthew Mitchell
# 12         Jessica Weiss
# 13        Olivia Freeman
# 14         Alexa Winters
# 15          Laura Chavez
# 16       Katherine Jones
# 17           Lisa Harris
# 18        Stacey Ramirez
# 19        Jennifer Clark
# 20          Jill Fuentes
# 21          Richard Ross
# 22        Teresa Cameron
# 23       Jessica Rodgers
# 24    Taylor Acevedo DDS
# 25         Kimberly Duke
# 26         Robert Martin
# 27          Zachary Bell
# 28       Ronnie Erickson
# 29           George Gray
# 30           Tammie Ford
# 31         Courtney Hart
# 32    Mrs. Patricia Tate
# 33        Jeremy Aguilar
# 34    Crystal Williamson
# 35          Jerry Madden
# 36           Rhonda Webb
# 37             Renee Lee
# 38       Rhonda Williams
# 39        Phillip Walker
# 40            Leroy Shaw
# 41           Amy Aguilar
# 42          Brendan Hill
# 43       Brandy Peterson
# 44          Jacob Guzman
# 45      Melissa Hamilton
# 46       Courtney Torres
# 47           Erik Romero
# 48        Mark Rodriguez
# 49          Sandra Banks
# Name: name, dtype: object
# (50,)
# col name and type: description & TEXT
# col name and type: created_at & TIMESTAMP
# ✅ Bulk insert complete for departments (duplicates skipped)
#
# --- Processing table: accounts ---
# col name and type: account_id & UUID
# col name and type: company_id & UUID
# col name and type: code & VARCHAR(20)
# 20
# 0     spa-06340
# 1     IIL-41010
# 2     ekA-99085
# 3     Din-06980
# 4     aFe-80130
# 5     JkE-64998
# 6     pMA-10374
# 7     bWp-02921
# 8     dca-21917
# 9     vCx-12091
# 10    czd-40330
# 11    KeW-88541
# 12    tdQ-41694
# 13    xcR-99194
# 14    Lgs-02244
# 15    oSn-64113
# 16    eIs-11442
# 17    buA-91413
# 18    Jbt-95562
# 19    MCk-61891
# 20    ozg-52939
# 21    Pgq-35685
# 22    Jfr-71828
# 23    YVh-97358
# 24    nnU-93110
# 25    xrT-94724
# 26    JaG-84351
# 27    IBY-97089
# 28    zGC-83451
# 29    DWm-22590
# 30    uWO-42296
# 31    LBP-33477
# 32    qtv-59125
# 33    FtU-26322
# 34    rBA-18342
# 35    mfy-56065
# 36    YRc-68022
# 37    JoH-95845
# 38    yrx-92138
# 39    HMs-17053
# 40    tfy-66657
# 41    PlO-73251
# 42    Bfd-06527
# 43    RMY-91343
# 44    VOA-27979
# 45    UhW-91291
# 46    FOE-11003
# 47    klx-58246
# 48    JjG-27994
# 49    OSS-23953
# Name: code, dtype: object
# (50,)
# col name and type: name & VARCHAR(255)
# 255
# 0          Anthony Acevedo
# 1              David Smith
# 2      Katrina Mcbride DVM
# 3               Lisa Oneal
# 4           Katherine Rios
# 5              Janet Perry
# 6             Kevin Kaiser
# 7          Brandon Johnson
# 8         Jennifer Burgess
# 9     Dr. Francisco Levine
# 10             Scott Moore
# 11            Erica Thomas
# 12            Alexis Perez
# 13           Denise Garcia
# 14              Roger Shah
# 15           Hector Madden
# 16        Jeffrey Williams
# 17      Kathleen Nicholson
# 18           Jeffrey Mckay
# 19              Laura Ross
# 20    Elizabeth Mccullough
# 21             Dawn Knight
# 22            Jason Murphy
# 23            Edwin Hebert
# 24         Brianna Rowland
# 25         Stephen Johnson
# 26        Kimberly Johnson
# 27        Christopher Kent
# 28           Johnny Tanner
# 29          Roberto Garcia
# 30               Paul Reed
# 31        Ashley Baird DDS
# 32               Jill Vang
# 33          Jessica Deleon
# 34             Lori Bishop
# 35        Alexis Carpenter
# 36           Kendra Powers
# 37        Nicholas Ballard
# 38            Hunter Moran
# 39       Desiree Hernandez
# 40              John Brady
# 41           Joshua Kelley
# 42          Charles Cooper
# 43           Jessica Jones
# 44         Chelsea Johnson
# 45           Kelly Coleman
# 46         Melinda Perkins
# 47         Kristen Morales
# 48            Marcus Hines
# 49            Paula Wilson
# Name: name, dtype: object
# (50,)
# col name and type: type & VARCHAR(20)
# 20
# 0        credit
# 1        income
# 2        income
# 3        credit
# 4         asset
# 5        income
# 6       expense
# 7     liability
# 8        credit
# 9        equity
# 10       income
# 11      expense
# 12       credit
# 13       equity
# 14        asset
# 15        debit
# 16        asset
# 17    liability
# 18       credit
# 19      expense
# 20       equity
# 21        asset
# 22       equity
# 23        asset
# 24      expense
# 25       credit
# 26      expense
# 27      expense
# 28    liability
# 29      expense
# 30      expense
# 31       income
# 32        debit
# 33       credit
# 34        debit
# 35      expense
# 36       equity
# 37        debit
# 38        asset
# 39        asset
# 40        asset
# 41       credit
# 42        debit
# 43        asset
# 44       equity
# 45    liability
# 46       equity
# 47        debit
# 48       equity
# 49        asset
# Name: type, dtype: object
# (50,)
# col name and type: parent_account_id & UUID
# col name and type: created_at & TIMESTAMP
# col name and type: is_active & BOOLEAN
# ❌ Integrity error for accounts: (psycopg2.errors.ForeignKeyViolation) insert or update on table "accounts" violates foreign key constraint "accounts_parent_account_id_fkey"
# DETAIL:  Key (parent_account_id)=(52c21ddd-46f4-449c-8e30-1cd1153333c7) is not present in table "accounts".
#
# [SQL: INSERT INTO accounts (account_id, company_id, code, name, type, parent_account_id, created_at, is_active) VALUES (%(account_id_m0)s::UUID, %(company_id_m0)s::UUID, %(code_m0)s, %(name_m0)s, %(type_m0)s, %(parent_account_id_m0)s::UUID, %(created_at_m0)s, %(is_active_m0)s), (%(account_id_m1)s::UUID, %(company_id_m1)s::UUID, %(code_m1)s, %(name_m1)s, %(type_m1)s, %(parent_account_id_m1)s::UUID, %(created_at_m1)s, %(is_active_m1)s), (%(account_id_m2)s::UUID, %(company_id_m2)s::UUID, %(code_m2)s, %(name_m2)s, %(type_m2)s, %(parent_account_id_m2)s::UUID, %(created_at_m2)s, %(is_active_m2)s), (%(account_id_m3)s::UUID, %(company_id_m3)s::UUID, %(code_m3)s, %(name_m3)s, %(type_m3)s, %(parent_account_id_m3)s::UUID, %(created_at_m3)s, %(is_active_m3)s), (%(account_id_m4)s::UUID, %(company_id_m4)s::UUID, %(code_m4)s, %(name_m4)s, %(type_m4)s, %(parent_account_id_m4)s::UUID, %(created_at_m4)s, %(is_active_m4)s), (%(account_id_m5)s::UUID, %(company_id_m5)s::UUID, %(code_m5)s, %(name_m5)s, %(type_m5)s, %(parent_account_id_m5)s::UUID, %(created_at_m5)s, %(is_active_m5)s), (%(account_id_m6)s::UUID, %(company_id_m6)s::UUID, %(code_m6)s, %(name_m6)s, %(type_m6)s, %(parent_account_id_m6)s::UUID, %(created_at_m6)s, %(is_active_m6)s), (%(account_id_m7)s::UUID, %(company_id_m7)s::UUID, %(code_m7)s, %(name_m7)s, %(type_m7)s, %(parent_account_id_m7)s::UUID, %(created_at_m7)s, %(is_active_m7)s), (%(account_id_m8)s::UUID, %(company_id_m8)s::UUID, %(code_m8)s, %(name_m8)s, %(type_m8)s, %(parent_account_id_m8)s::UUID, %(created_at_m8)s, %(is_active_m8)s), (%(account_id_m9)s::UUID, %(company_id_m9)s::UUID, %(code_m9)s, %(name_m9)s, %(type_m9)s, %(parent_account_id_m9)s::UUID, %(created_at_m9)s, %(is_active_m9)s), (%(account_id_m10)s::UUID, %(company_id_m10)s::UUID, %(code_m10)s, %(name_m10)s, %(type_m10)s, %(parent_account_id_m10)s::UUID, %(created_at_m10)s, %(is_active_m10)s), (%(account_id_m11)s::UUID, %(company_id_m11)s::UUID, %(code_m11)s, %(name_m11)s, %(type_m11)s, %(parent_account_id_m11)s::UUID, %(created_at_m11)s, %(is_active_m11)s), (%(account_id_m12)s::UUID, %(company_id_m12)s::UUID, %(code_m12)s, %(name_m12)s, %(type_m12)s, %(parent_account_id_m12)s::UUID, %(created_at_m12)s, %(is_active_m12)s), (%(account_id_m13)s::UUID, %(company_id_m13)s::UUID, %(code_m13)s, %(name_m13)s, %(type_m13)s, %(parent_account_id_m13)s::UUID, %(created_at_m13)s, %(is_active_m13)s), (%(account_id_m14)s::UUID, %(company_id_m14)s::UUID, %(code_m14)s, %(name_m14)s, %(type_m14)s, %(parent_account_id_m14)s::UUID, %(created_at_m14)s, %(is_active_m14)s), (%(account_id_m15)s::UUID, %(company_id_m15)s::UUID, %(code_m15)s, %(name_m15)s, %(type_m15)s, %(parent_account_id_m15)s::UUID, %(created_at_m15)s, %(is_active_m15)s), (%(account_id_m16)s::UUID, %(company_id_m16)s::UUID, %(code_m16)s, %(name_m16)s, %(type_m16)s, %(parent_account_id_m16)s::UUID, %(created_at_m16)s, %(is_active_m16)s), (%(account_id_m17)s::UUID, %(company_id_m17)s::UUID, %(code_m17)s, %(name_m17)s, %(type_m17)s, %(parent_account_id_m17)s::UUID, %(created_at_m17)s, %(is_active_m17)s), (%(account_id_m18)s::UUID, %(company_id_m18)s::UUID, %(code_m18)s, %(name_m18)s, %(type_m18)s, %(parent_account_id_m18)s::UUID, %(created_at_m18)s, %(is_active_m18)s), (%(account_id_m19)s::UUID, %(company_id_m19)s::UUID, %(code_m19)s, %(name_m19)s, %(type_m19)s, %(parent_account_id_m19)s::UUID, %(created_at_m19)s, %(is_active_m19)s), (%(account_id_m20)s::UUID, %(company_id_m20)s::UUID, %(code_m20)s, %(name_m20)s, %(type_m20)s, %(parent_account_id_m20)s::UUID, %(created_at_m20)s, %(is_active_m20)s), (%(account_id_m21)s::UUID, %(company_id_m21)s::UUID, %(code_m21)s, %(name_m21)s, %(type_m21)s, %(parent_account_id_m21)s::UUID, %(created_at_m21)s, %(is_active_m21)s), (%(account_id_m22)s::UUID, %(company_id_m22)s::UUID, %(code_m22)s, %(name_m22)s, %(type_m22)s, %(parent_account_id_m22)s::UUID, %(created_at_m22)s, %(is_active_m22)s), (%(account_id_m23)s::UUID, %(company_id_m23)s::UUID, %(code_m23)s, %(name_m23)s, %(type_m23)s, %( ...
# [parameters: {'account_id_m0': '6e9b6ab8-0323-4a9c-8a1c-716cf5597b07', 'company_id_m0': 'ff90357e-79ca-4bca-9810-9327cf93bf59', 'code_m0': 'spa-06340', 'name_m0': 'Anthony Acevedo', 'type_m0': 'credit', 'parent_account_id_m0': '52c21ddd-46f4-449c-8e30-1cd1153333c7', 'created_at_m0': '2025-02-17 00:46:42', 'is_active_m0': True, 'account_id_m1': '85e3358a-017f-4abf-a041-89f829518d17', 'company_id_m1': '8e4e17b4-7637-4958-9391-31f546b9da95', 'code_m1': 'IIL-41010', 'name_m1': 'David Smith', 'type_m1': 'income', 'parent_account_id_m1': '6e9b6ab8-0323-4a9c-8a1c-716cf5597b07', 'created_at_m1': '2024-10-04 19:10:34', 'is_active_m1': True, 'account_id_m2': '8724a1cd-898a-4cfb-8e1d-872067e91e2e', 'company_id_m2': '474f07c5-fdba-47fc-92aa-102a9d943e15', 'code_m2': 'ekA-99085', 'name_m2': 'Katrina Mcbride DVM', 'type_m2': 'income', 'parent_account_id_m2': '6e9b6ab8-0323-4a9c-8a1c-716cf5597b07', 'created_at_m2': '2024-02-22 14:02:27', 'is_active_m2': True, 'account_id_m3': '29a4256c-f33c-4dc5-9f10-0be47fda9298', 'company_id_m3': '5f84b9d2-ea42-4b8f-ba29-a080f089a87e', 'code_m3': 'Din-06980', 'name_m3': 'Lisa Oneal', 'type_m3': 'credit', 'parent_account_id_m3': '6e9b6ab8-0323-4a9c-8a1c-716cf5597b07', 'created_at_m3': '2023-11-04 22:30:14', 'is_active_m3': False, 'account_id_m4': 'd6d68d21-2aa3-472d-bbd3-df3a64540907', 'company_id_m4': 'e6e7feaa-8de8-44a3-a959-718a50704464', 'code_m4': 'aFe-80130', 'name_m4': 'Katherine Rios', 'type_m4': 'asset', 'parent_account_id_m4': '29a4256c-f33c-4dc5-9f10-0be47fda9298', 'created_at_m4': '2023-04-25 02:29:35', 'is_active_m4': False, 'account_id_m5': '04df4502-4406-486e-b395-de98538762f8', 'company_id_m5': '107733f4-39a9-4f93-b740-21b5da132d12', 'code_m5': 'JkE-64998', 'name_m5': 'Janet Perry', 'type_m5': 'income', 'parent_account_id_m5': 'd6d68d21-2aa3-472d-bbd3-df3a64540907', 'created_at_m5': '2023-10-29 01:40:24', 'is_active_m5': True, 'account_id_m6': '3584f9b2-8ab3-4cc8-a395-5ef141e61b64', 'company_id_m6': 'eb1abbba-cf12-42ed-b25e-26ad6cb78a67' ... 300 parameters truncated ... 'created_at_m43': '2023-12-11 06:46:29', 'is_active_m43': True, 'account_id_m44': 'e57c7582-a57b-4d54-aef3-e8fb71ffa30f', 'company_id_m44': '107733f4-39a9-4f93-b740-21b5da132d12', 'code_m44': 'VOA-27979', 'name_m44': 'Chelsea Johnson', 'type_m44': 'equity', 'parent_account_id_m44': '262be5aa-bfbb-46e6-8c27-1b96d24b73ef', 'created_at_m44': '2022-09-03 13:34:12', 'is_active_m44': True, 'account_id_m45': 'b4f522e2-217c-47d4-9879-45a12c5787ce', 'company_id_m45': '107733f4-39a9-4f93-b740-21b5da132d12', 'code_m45': 'UhW-91291', 'name_m45': 'Kelly Coleman', 'type_m45': 'liability', 'parent_account_id_m45': '6e7462e0-14e0-4d7f-8439-8f105bd55d75', 'created_at_m45': '2023-09-06 03:47:07', 'is_active_m45': False, 'account_id_m46': '39f0bcc3-a645-4373-bfc8-a9fb671816eb', 'company_id_m46': '4f12c98b-2fe9-45c2-b71c-08b378181569', 'code_m46': 'FOE-11003', 'name_m46': 'Melinda Perkins', 'type_m46': 'equity', 'parent_account_id_m46': 'f5c1ce18-d862-45ad-9da1-8f67129ed4cb', 'created_at_m46': '2022-12-31 05:36:04', 'is_active_m46': True, 'account_id_m47': 'af3498f5-869d-4606-8cc8-485292ff3bb4', 'company_id_m47': '8c7f0b27-6c32-4530-9d32-e6c04875d130', 'code_m47': 'klx-58246', 'name_m47': 'Kristen Morales', 'type_m47': 'debit', 'parent_account_id_m47': 'a873e5e0-9105-40a2-aae8-e6847d0455a7', 'created_at_m47': '2022-10-22 21:35:45', 'is_active_m47': True, 'account_id_m48': '0b29f9ad-8f05-465b-aeba-02442a003145', 'company_id_m48': 'a109ccb3-a778-4508-8d4d-b0c170e4765b', 'code_m48': 'JjG-27994', 'name_m48': 'Marcus Hines', 'type_m48': 'equity', 'parent_account_id_m48': 'dd7d72b3-a248-4fa8-9148-9a4513a77dfe', 'created_at_m48': '2023-11-12 00:09:16', 'is_active_m48': False, 'account_id_m49': 'da23dad0-6132-43a1-8059-4d480de8ee85', 'company_id_m49': '8e4e17b4-7637-4958-9391-31f546b9da95', 'code_m49': 'OSS-23953', 'name_m49': 'Paula Wilson', 'type_m49': 'asset', 'parent_account_id_m49': 'dd7d72b3-a248-4fa8-9148-9a4513a77dfe', 'created_at_m49': '2023-08 ...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# --- Processing table: customers ---
# col name and type: customer_id & UUID
# col name and type: company_id & UUID
# col name and type: name & VARCHAR(255)
# 255
# 0           Stephanie Allen
# 1             Terry Edwards
# 2               Adam Harmon
# 3             Ashley Steele
# 4           Michael Wallace
# 5              Melvin Blair
# 6           Jennifer Fisher
# 7             Zachary Davis
# 8          Colleen Galloway
# 9              Tyler Taylor
# 10           William Morgan
# 11               Doris Reed
# 12             Felicia Hale
# 13            Sabrina Moore
# 14              Miranda Lee
# 15            Rachel Castro
# 16               Marie Tran
# 17           William Vargas
# 18              Rhonda Kirk
# 19         Angelica Jackson
# 20           Michael Rivers
# 21             Lori Kennedy
# 22           Daniel Rodgers
# 23            Douglas Riley
# 24               Aaron Hays
# 25             Joshua Young
# 26           Sophia Holland
# 27          Mr. David Banks
# 28           George Griffin
# 29              Michael Fox
# 30       Christopher Tucker
# 31           Yolanda Herman
# 32              Brittany Le
# 33             Joshua Allen
# 34            Dillon Parker
# 35          Johnny Mcintosh
# 36           Mason Caldwell
# 37             Douglas Hale
# 38           Allison Miller
# 39            Shawn Jackson
# 40    Mr. Aaron Leonard DVM
# 41            Taylor Baxter
# 42        Jennifer Marshall
# 43             William Holt
# 44          Caroline Prince
# 45           Thomas Jackson
# 46              Ashley King
# 47                Ann Casey
# 48            Lisa Martinez
# 49            Donald Martin
# Name: name, dtype: object
# (50,)
# col name and type: gstin & VARCHAR(15)
# 15
# 0     rw933208026
# 1     aJ423003591
# 2     LK481267675
# 3     ZN653714677
# 4     Wy796283911
# 5     PU464280307
# 6     Yu427701471
# 7     Ap866070609
# 8     uR642364315
# 9     px479648321
# 10    xZ682755506
# 11    IV628664216
# 12    yC697610107
# 13    La222394751
# 14    pa695798460
# 15    Qe317187133
# 16    pf564386707
# 17    TH131627863
# 18    kH324177923
# 19    ru992008918
# 20    Nu286120531
# 21    RU091882539
# 22    ni205778974
# 23    Id254804986
# 24    pI832057315
# 25    YD112860340
# 26    FB379960614
# 27    ou260261049
# 28    er021944701
# 29    cw771579122
# 30    ma949991163
# 31    Kx178036305
# 32    ov454365420
# 33    UH679523646
# 34    ke720610864
# 35    Kh396998749
# 36    gG319848717
# 37    jJ957474084
# 38    EM740735572
# 39    Zp328699631
# 40    hn820476077
# 41    AX589270796
# 42    PE259441299
# 43    gE580771321
# 44    Uj465397797
# 45    NN536963220
# 46    sT833082654
# 47    NF778998877
# 48    Wt970934664
# 49    JV697969113
# Name: gstin, dtype: object
# (50,)
# col name and type: address & TEXT
# col name and type: city & VARCHAR(100)
# 100
# 0      East Nicholashaven
# 1               Justinton
# 2               Port Anna
# 3            West Zachary
# 4             Josephmouth
# 5           West Joelview
# 6             Charlestown
# 7                East Amy
# 8         Port Robertberg
# 9        West Kristinfurt
# 10            Jessicaland
# 11          New Sarahside
# 12        Harrisonchester
# 13             North Gina
# 14                Toddton
# 15               Pughtown
# 16            North Tammy
# 17          Rachelborough
# 18      New Michelleshire
# 19              Nancyport
# 20      South Josephshire
# 21             Kelseyfort
# 22       West Valeriebury
# 23            Reynoldston
# 24            East Tricia
# 25             Gilbertton
# 26            Timothyland
# 27              Smithbury
# 28            Jeffreyport
# 29        East Aprilburgh
# 30         South Michelle
# 31              East Eric
# 32          South Rebecca
# 33        New Williamstad
# 34          Lake Masonton
# 35         New Robertfurt
# 36              Laurieton
# 37            East Robert
# 38        North Chaseside
# 39              North Amy
# 40    South Alejandroside
# 41            Jeffreyview
# 42          South Melissa
# 43            Williamview
# 44       South Deannaport
# 45            Stewartfort
# 46       New Candaceshire
# 47        New Matthewbury
# 48            Lawsonmouth
# 49            Williamfurt
# Name: city, dtype: object
# (50,)
# col name and type: state & VARCHAR(100)
# 100
# 0               Utah
# 1     North Carolina
# 2           Missouri
# 3           Virginia
# 4         New Jersey
# 5               Utah
# 6              Texas
# 7     North Carolina
# 8              Maine
# 9       Pennsylvania
# 10          New York
# 11           Indiana
# 12    North Carolina
# 13            Alaska
# 14          Oklahoma
# 15           Georgia
# 16          Arkansas
# 17            Oregon
# 18          Arkansas
# 19          Delaware
# 20            Hawaii
# 21           Florida
# 22         Minnesota
# 23           Indiana
# 24          Colorado
# 25           Vermont
# 26           Indiana
# 27              Ohio
# 28          Missouri
# 29         Louisiana
# 30           Arizona
# 31         Tennessee
# 32           Arizona
# 33          Missouri
# 34           Montana
# 35           Vermont
# 36     West Virginia
# 37    North Carolina
# 38            Alaska
# 39       Connecticut
# 40          Nebraska
# 41           Arizona
# 42             Maine
# 43              Iowa
# 44           Indiana
# 45       Connecticut
# 46            Nevada
# 47          Colorado
# 48      South Dakota
# 49          Illinois
# Name: state, dtype: object
# (50,)
# col name and type: country & VARCHAR(100)
# 100
# 0                                           Monaco
# 1                                    Guinea-Bissau
# 2                                          Morocco
# 3                                       Martinique
# 4                                          Ireland
# 5                                          Tunisia
# 6                                    Faroe Islands
# 7                                    Guinea-Bissau
# 8                                         Honduras
# 9                                           Angola
# 10                                         Mayotte
# 11                     Falkland Islands (Malvinas)
# 12                                           Macao
# 13               Heard Island and McDonald Islands
# 14                                         Bolivia
# 15                                         Jamaica
# 16                                  Czech Republic
# 17                                           Aruba
# 18                                           Italy
# 19                                        Colombia
# 20                                           Gabon
# 21                                        Suriname
# 22                                           Italy
# 23                                        Portugal
# 24                              Russian Federation
# 25                                         Germany
# 26                                           Gabon
# 27                                Pitcairn Islands
# 28    South Georgia and the South Sandwich Islands
# 29                                      Luxembourg
# 30                           Palestinian Territory
# 31                                          Tuvalu
# 32                                          Latvia
# 33                       Bouvet Island (Bouvetoya)
# 34                                       Singapore
# 35                                        Suriname
# 36                                     New Zealand
# 37                                           Samoa
# 38                                           Macao
# 39                                     Timor-Leste
# 40                                         Burundi
# 41                                         Croatia
# 42                                       Sri Lanka
# 43                                        Djibouti
# 44                                        Dominica
# 45                                    Burkina Faso
# 46                                        Dominica
# 47                                         Bahamas
# 48                                    Cook Islands
# 49                               Equatorial Guinea
# Name: country, dtype: object
# (50,)
# col name and type: contact_person & VARCHAR(100)
# 100
# 0      +1-271-902-8532x72214
# 1      001-614-239-9898x4126
# 2        +1-355-230-5683x133
# 3        +1-234-697-8811x081
# 4         416.811.1693x56816
# 5      001-487-265-2300x3849
# 6           697-569-7756x415
# 7          (874)501-1107x151
# 8              (937)729-3226
# 9         537-200-1622x41797
# 10              334-769-0094
# 11    001-938-491-8103x03977
# 12        988-631-6321x21002
# 13              470-731-2080
# 14      +1-796-415-8241x2062
# 15      001-711-799-0193x235
# 16        262-770-8766x14565
# 17       (822)341-8291x57835
# 18                9659230735
# 19         866-290-9394x6784
# 20          235-390-4137x000
# 21        (409)317-3690x9273
# 22          789.532.9795x216
# 23        525-391-4492x22858
# 24       (805)914-1620x61199
# 25      +1-500-856-9931x5535
# 26              706.830.9206
# 27         (497)563-6169x770
# 28        734.741.9372x85146
# 29              690.770.2767
# 30          918.578.3924x861
# 31     001-999-549-0536x9628
# 32         452-660-3055x0933
# 33     001-670-760-7372x7166
# 34           +1-478-982-6613
# 35                5165896492
# 36              506-374-5479
# 37     +1-863-610-8666x23135
# 38     +1-993-443-3274x38399
# 39                7914764216
# 40         (453)463-3735x294
# 41              357-495-3799
# 42           +1-530-221-2053
# 43       +1-796-913-4418x828
# 44              301.822.7762
# 45       +1-418-812-3819x462
# 46                4122204619
# 47     +1-263-623-6109x06714
# 48             (560)852-6236
# 49        278.467.8950x60570
# Name: contact_person, dtype: object
# (50,)
# col name and type: email & VARCHAR(255)
# 255
# 0             salaslaura@example.com
# 1        murphyelizabeth@example.net
# 2             kimberly44@example.org
# 3               amanda35@example.org
# 4                 tbowen@example.com
# 5           robertdaniel@example.net
# 6                zmorris@example.org
# 7               spadilla@example.com
# 8                  hwong@example.com
# 9               tonygill@example.net
# 10                xgreen@example.net
# 11            kempwalter@example.net
# 12           patrickreid@example.net
# 13         valdezmichael@example.org
# 14       wallacejennifer@example.org
# 15          susanedwards@example.net
# 16               lfuller@example.com
# 17         heatherturner@example.com
# 18           karenthomas@example.org
# 19         victoriamccoy@example.org
# 20         brianrobinson@example.org
# 21             lthompson@example.org
# 22         shirleyjarvis@example.net
# 23             jessica88@example.org
# 24                pyoung@example.net
# 25          bradleyjones@example.org
# 26               jenna67@example.net
# 27               kayla27@example.org
# 28             smithjohn@example.org
# 29               vlarson@example.net
# 30               carla01@example.com
# 31           thomasreyes@example.org
# 32                hkelly@example.com
# 33              qmaxwell@example.com
# 34            michelle01@example.com
# 35                 mware@example.net
# 36               randy94@example.net
# 37               bnguyen@example.org
# 38         dorothylevine@example.net
# 39               david74@example.com
# 40                iparks@example.com
# 41          meganroberts@example.org
# 42              nvincent@example.com
# 43                fjohns@example.com
# 44              evelyn78@example.com
# 45         bradleygraham@example.net
# 46            carrielamb@example.com
# 47    theodorerichardson@example.net
# 48           conniejones@example.com
# 49              ehopkins@example.org
# Name: email, dtype: object
# (50,)
# col name and type: phone & VARCHAR(20)
# 20
# 0             873-431-3868
# 1             804.955.4212
# 2        300-742-6279x9096
# 3     001-623-425-4442x385
# 4      +1-317-808-5478x116
# 5            (543)205-0395
# 6          +1-923-710-4665
# 7     001-851-603-2399x213
# 8       299-841-3537x65152
# 9               7108895396
# 10      662-300-7018x92782
# 11            407-915-1466
# 12       786-418-8848x8135
# 13            573.418.2613
# 14    +1-599-529-3527x8152
# 15        964-642-7702x444
# 16            407.237.2667
# 17            496-603-2336
# 18        797.737.9348x852
# 19      805-895-9281x33856
# 20      461-342-2147x66867
# 21            428-871-9650
# 22            998-589-2910
# 23           (815)522-8451
# 24            305-216-6891
# 25     (472)678-4302x56284
# 26    +1-530-752-6530x3054
# 27       675-369-3347x0540
# 28        295.897.8481x553
# 29       (666)353-8726x805
# 30       954-269-7478x3396
# 31       399.930.2773x2752
# 32            268.548.6392
# 33        001-524-329-3915
# 34              4023301466
# 35            885-608-4877
# 36            305-932-2908
# 37    001-642-604-1276x977
# 38      912.525.2473x29760
# 39    +1-736-413-6160x1508
# 40    +1-574-688-9425x9853
# 41        392.622.5194x692
# 42              7678446041
# 43              2794426290
# 44        529-701-3678x835
# 45        001-299-338-5499
# 46       835-690-9002x3584
# 47       (463)388-9580x883
# 48     (568)859-1991x33896
# 49       789-518-6099x8414
# Name: phone, dtype: object
# (50,)
# col name and type: credit_limit & NUMERIC(15, 2)
# col name and type: created_at & TIMESTAMP
# col name and type: is_active & BOOLEAN
# ✅ Bulk insert complete for customers (duplicates skipped)
#
# --- Processing table: vendors ---
# col name and type: vendor_id & UUID
# col name and type: company_id & UUID
# col name and type: name & VARCHAR(255)
# 255
# 0         Brooke Maldonado
# 1               Scott Ryan
# 2             Wendy Morrow
# 3               Eric Smith
# 4              James Cline
# 5           Matthew Walker
# 6             Keith Little
# 7         Sandra Carpenter
# 8             Cheryl Villa
# 9           Allison Duncan
# 10            Anita Melton
# 11         Maurice Johnson
# 12             John Keller
# 13           Chloe Sanders
# 14        Savannah Coleman
# 15          Rachel Sanchez
# 16             Brandi York
# 17           Nathan Bryant
# 18             Nicole Lutz
# 19            Regina Mckee
# 20             Maria Grant
# 21            Rachel Lewis
# 22             Paula Davis
# 23             Thomas Chen
# 24             Anna French
# 25        Margaret Jimenez
# 26          Michael Lucero
# 27           Michael Evans
# 28        Elizabeth Keller
# 29        William Mcdaniel
# 30             Ryan Brooks
# 31           Jose Griffith
# 32    Dr. Samantha Tran MD
# 33         Adrienne Wilson
# 34           Mary Griffith
# 35          Karen Martinez
# 36           Karen Robbins
# 37              Alex Lewis
# 38           Wesley Bowers
# 39            James Powell
# 40              Anne Lopez
# 41           Raymond Smith
# 42         Teresa Morrison
# 43             David Davis
# 44             Bryan Jones
# 45            Troy Buckley
# 46          Gabriela Gomez
# 47            Steven Evans
# 48        Christopher Owen
# 49            Wendy Murphy
# Name: name, dtype: object
# (50,)
# col name and type: gstin & VARCHAR(15)
# 15
# 0     Zs932232310
# 1     ZB103713735
# 2     bb505573229
# 3     lP971376788
# 4     dh940378128
# 5     Sh491362996
# 6     Qk604323954
# 7     Sy685869167
# 8     Lb692644616
# 9     nE653179666
# 10    gw665392023
# 11    RV866491860
# 12    gZ389983743
# 13    QV511254435
# 14    Ea970490406
# 15    jg404529391
# 16    lL298313017
# 17    GQ455121555
# 18    hl713696385
# 19    ai954565202
# 20    Vl211897851
# 21    PO824273767
# 22    Pd629321661
# 23    eT749264664
# 24    AU554040842
# 25    IM221243915
# 26    TK187025307
# 27    iM708964316
# 28    fO838944395
# 29    kU799007376
# 30    MX914978523
# 31    Ui967616435
# 32    BE489648609
# 33    Eq474660924
# 34    hu914638355
# 35    MS314802138
# 36    Dz393929378
# 37    vM952857287
# 38    aK972575271
# 39    Yr355207519
# 40    rY822844547
# 41    hq040691276
# 42    jS184913885
# 43    Hd968440600
# 44    wy313810782
# 45    om942874451
# 46    Ye829953037
# 47    TI766840565
# 48    fL235066832
# 49    yo502668488
# Name: gstin, dtype: object
# (50,)
# col name and type: address & TEXT
# col name and type: city & VARCHAR(100)
# 100
# 0          North Richard
# 1                Amyberg
# 2           Lanceborough
# 3         West Kaylastad
# 4               Sarahton
# 5           West Jessica
# 6               Jonville
# 7       South Sandrafort
# 8        East Michaelton
# 9             Scottville
# 10              Owenfort
# 11            Pamelastad
# 12         Villanuevaton
# 13               New Amy
# 14      South Danielview
# 15          Michelleland
# 16         Rodriguezland
# 17          East Roytown
# 18             Mistyview
# 19           Edwardville
# 20     Lake Michellefort
# 21           Johnsonstad
# 22            Mooremouth
# 23             Smithport
# 24         Margaretshire
# 25          Port Michael
# 26       North Christine
# 27         New Kristaton
# 28             Whitetown
# 29           Timothyfurt
# 30           Claytonbury
# 31        South Lisaland
# 32            Taylorfort
# 33      Lake Angelahaven
# 34           Ashleyburgh
# 35          New Kimberly
# 36             Ortizberg
# 37     West Richardhaven
# 38    South Stephenmouth
# 39          South Hannah
# 40            Snyderstad
# 41        North Edwinton
# 42           Charlesberg
# 43          Lake Tiffany
# 44            Kevinburgh
# 45          South Martha
# 46      North Austinfurt
# 47       East Gordonstad
# 48             West Sara
# 49            Stevenside
# Name: city, dtype: object
# (50,)
# col name and type: state & VARCHAR(100)
# 100
# 0       South Dakota
# 1      Massachusetts
# 2           New York
# 3        Mississippi
# 4              Idaho
# 5              Maine
# 6           Delaware
# 7           Virginia
# 8            Alabama
# 9              Texas
# 10     West Virginia
# 11          Colorado
# 12          Nebraska
# 13     New Hampshire
# 14           Arizona
# 15             Maine
# 16         Minnesota
# 17      Pennsylvania
# 18           Indiana
# 19      South Dakota
# 20             Maine
# 21           Georgia
# 22    North Carolina
# 23            Nevada
# 24          Virginia
# 25      Rhode Island
# 26       Mississippi
# 27     Massachusetts
# 28           Arizona
# 29            Nevada
# 30          Virginia
# 31          Maryland
# 32          Michigan
# 33         Minnesota
# 34             Maine
# 35          Virginia
# 36         Tennessee
# 37          Kentucky
# 38            Kansas
# 39          Nebraska
# 40          Michigan
# 41             Texas
# 42           Georgia
# 43      Pennsylvania
# 44         Minnesota
# 45      South Dakota
# 46      Pennsylvania
# 47         Tennessee
# 48          Arkansas
# 49         Tennessee
# Name: state, dtype: object
# (50,)
# col name and type: country & VARCHAR(100)
# 100
# 0                                Argentina
# 1              Falkland Islands (Malvinas)
# 2                                     Mali
# 3                                  Vanuatu
# 4                                  Ukraine
# 5                               Mozambique
# 6                         Papua New Guinea
# 7                               Micronesia
# 8                        Wallis and Futuna
# 9                            Liechtenstein
# 10                                   China
# 11                                 Liberia
# 12                                 Georgia
# 13                              Costa Rica
# 14                                  Angola
# 15                                   Korea
# 16                                 Senegal
# 17                               Guatemala
# 18                                  Mexico
# 19                               Indonesia
# 20                        Pitcairn Islands
# 21                                   Qatar
# 22                  Libyan Arab Jamahiriya
# 23       Heard Island and McDonald Islands
# 24                                 Austria
# 25                             Netherlands
# 26                              Uzbekistan
# 27                                  Greece
# 28                               Australia
# 29                                  Monaco
# 30                               Mauritius
# 31                        French Polynesia
# 32                  British Virgin Islands
# 33                              Uzbekistan
# 34                                 Myanmar
# 35                                Paraguay
# 36                                Djibouti
# 37    United States Minor Outlying Islands
# 38                                   Korea
# 39                                   Gabon
# 40                  Bosnia and Herzegovina
# 41                                 Belgium
# 42                          Western Sahara
# ...
# 40    Water high nothing own family become continue....
# 41    Home dinner too begin at. Believe its several ...
# 42    Day last society happy us now center. Space gr...
# 43    Dog area threat same. Western left news resour...
# 44    Member claim table do rather of may. Near poss...
# 45    Serve center stock. Scene building carry durin...
# 46    Clearly off a resource consumer product leader...
# 47    Movement drive yeah coach. Someone necessary s...
# 48    Less street really message operation house nor...
# 49    Travel address summer. Evidence network letter...
# Name: razorpay_order_id, dtype: object
# (50,)
# col name and type: razorpay_payment_id & VARCHAR(255)
# 255
# 0     Live live possible degree pick yet.\nOnly spec...
# 1     Second partner TV but race world. Individual c...
# 2     Medical money together both know baby want. Ar...
# 3     Never rise Democrat far discover with some. St...
# 4     Sense hand black individual from. Prepare cult...
# 5     Take simple production none remain. Fund deter...
# 6     Suddenly example your study consumer career wa...
# 7     Local trade just. Per will term conference if....
# 8     Send early discover scientist. Share individua...
# 9     Method always race quality care two return. Mi...
# 10    Even value recent performance push right. Deta...
# 11    Until water use capital next worker important....
# 12    Result whose she job. Mr laugh month successfu...
# 13    How effect Republican second. Better range sol...
# 14    Voice tough citizen represent short whether ar...
# 15    Box more really during character. Most recent ...
# 16    Another quickly building think professional. S...
# 17    Remember part structure. Meeting commercial so...
# 18    At course suddenly record. Great owner bit pic...
# 19    Let space little effort reveal president him. ...
# 20    Republican nation pretty physical. Often ball ...
# 21    Prepare institution though political. Recogniz...
# 22    Blood crime because somebody. Ahead apply lay ...
# 23    Challenge either necessary unit around daughte...
# 24    Month less establish officer. Pressure persona...
# 25    Teacher according evening each. Stock recogniz...
# 26    Care here family green industry. Power travel ...
# 27    Certainly last sign really my. Hotel drug rath...
# 28    Their radio heavy detail window find. Least ag...
# 29    Discuss because and. Knowledge once no citizen...
# 30    Character choose property wait direction respo...
# 31    Economic just education change loss here paper...
# 32    Life since cultural measure perform speech eve...
# 33    Third my foot article still. Entire environmen...
# 34    Financial over include well child cold. Face c...
# 35    Black truth half memory because begin. Middle ...
# 36    Deep information even brother. Adult doctor to...
# 37    Simply scientist less whose successful fine. S...
# 38    Suggest make vote study. Size shake teach very...
# 39    Manager interest talk his color. Science vote ...
# 40    Bed perhaps must compare blood involve bad mod...
# 41    Item remember new anyone system somebody. Writ...
# 42    Trade successful treatment though better exper...
# 43    Democratic tough either peace may. Change thin...
# 44    Similar simply very hospital technology. Of te...
# 45    Despite save far teach. Summer somebody great ...
# 46    Surface decade investment even. Marriage ever ...
# 47    Rather eight American financial. Research eith...
# 48    Television weight star series exactly close.\n...
# 49    Choose summer may else red speech. Table analy...
# Name: razorpay_payment_id, dtype: object
# (50,)
# col name and type: created_at & TIMESTAMP
# ✅ Bulk insert complete for payments (duplicates skipped)
#
# --- Processing table: email_verifications ---
# col name and type: verification_id & UUID
# col name and type: user_id & UUID
# col name and type: email & VARCHAR(255)
# 255
# 0            lyonsrobert@example.com
# 1                karen23@example.net
# 2            amandayoder@example.net
# 3               steven35@example.org
# 4           lauriemontes@example.org
# 5         reynoldsjoshua@example.org
# 6         jonathanflores@example.com
# 7              roberto46@example.net
# 8                 mark83@example.org
# 9             krodriguez@example.net
# 10             pricechad@example.net
# 11            lisaturner@example.org
# 12           taylorbrian@example.org
# 13             nbartlett@example.net
# 14                todd16@example.org
# 15               rwagner@example.com
# 16           moralesanna@example.net
# 17               kevin60@example.com
# 18                fyoung@example.org
# 19               ejensen@example.net
# 20           cruzjeffery@example.org
# 21     hernandezmichelle@example.com
# 22               carol04@example.org
# 23            margaret55@example.net
# 24         ashleybernard@example.net
# 25                 iboyd@example.org
# 26           denisejames@example.net
# 27            brianknapp@example.net
# 28                adam55@example.org
# 29              sgilmore@example.org
# 30              deanna21@example.org
# 31          juananderson@example.com
# 32                sglass@example.org
# 33               ycastro@example.com
# 34              bfreeman@example.net
# 35             patrick20@example.org
# 36           smithalexis@example.org
# 37               peter01@example.com
# 38         martinezkayla@example.com
# 39                 phart@example.com
# 40          debbiemartin@example.net
# 41    christopherramirez@example.net
# 42        schroederaaron@example.org
# 43           beardsamuel@example.org
# 44       christinamiller@example.org
# 45           simmonstina@example.org
# 46           francisco51@example.com
# 47           adamelliott@example.com
# 48           catherine94@example.org
# 49              carrie28@example.com
# Name: email, dtype: object
# (50,)
# col name and type: otp & VARCHAR(6)
# 6
# 0     921114
# 1     263449
# 2     175278
# 3     962147
# 4     859214
# 5     773900
# 6     696715
# 7     355585
# 8     512212
# 9     827875
# 10    760130
# 11    776545
# 12    416267
# 13    438578
# 14    430271
# 15    335045
# 16    137523
# 17    353699
# 18    241592
# 19    645344
# 20    553748
# 21    579126
# 22    357263
# 23    283639
# 24    641219
# 25    191214
# 26    718570
# 27    750384
# 28    788232
# 29    532420
# 30    100099
# 31    611570
# 32    899416
# 33    139773
# 34    500745
# 35    246540
# 36    704140
# 37    898883
# 38    459852
# 39    921217
# 40    852199
# 41    655731
# 42    529492
# 43    798330
# 44    849689
# 45    865197
# 46    143961
# 47    709245
# 48    761373
# 49    733780
# Name: otp, dtype: object
# (50,)
# col name and type: is_verified & BOOLEAN
# col name and type: created_at & TIMESTAMP
# col name and type: expires_at & TIMESTAMP
# ✅ Bulk insert complete for email_verifications (duplicates skipped)
#
# --- Processing table: phone_verifications ---
# col name and type: verification_id & UUID
# col name and type: user_id & UUID
# col name and type: phone_number & VARCHAR(20)
# 20
# 0       876-529-1488x26400
# 1      (492)312-3881x44294
# 2             988.566.2595
# 3     001-853-207-2271x516
# 4       740-977-4775x56627
# 5            (370)557-2634
# 6         563.773.6934x758
# 7             317-362-8977
# 8            (913)305-2249
# 9         001-462-714-2598
# 10    001-281-347-9898x992
# 11            419-738-8846
# 12            337-529-0288
# 13            523.724.3250
# 14      320.252.0029x08586
# 15            952.598.1933
# 16            888-785-8930
# 17    +1-347-465-2080x7100
# 18           (676)655-0128
# 19     +1-343-801-5593x710
# 20              9512533155
# 21       627.754.4647x4956
# 22              2226151663
# 23    +1-205-426-2898x5859
# 24    001-771-258-2627x962
# 25       (522)558-4702x163
# 26        001-504-592-7989
# 27        001-768-673-6775
# 28        896.890.1394x961
# 29      770-443-2438x83546
# 30           (284)436-5433
# 31           (601)879-9763
# 32        697-481-2903x727
# 33            872-940-2417
# 34     +1-335-752-6679x705
# 35         +1-267-675-2094
# 36              9745729938
# 37       (748)365-0027x585
# 38      (984)204-4574x3324
# 39              3054747021
# 40              6126141661
# 41           (487)890-8742
# 42       (492)446-7378x355
# 43        739-532-0313x894
# 44            412-210-5492
# 45     (715)521-6736x05311
# 46       582-650-1202x6163
# 47     +1-561-372-8692x858
# 48              5023524400
# 49     +1-963-684-8425x780
# Name: phone_number, dtype: object
# (50,)
# col name and type: otp & VARCHAR(6)
# 6
# 0     691837
# 1     829904
# 2     618193
# 3     138502
# 4     102952
# 5     883291
# 6     621799
# 7     375479
# 8     284991
# 9     164816
# 10    219089
# 11    852806
# 12    204156
# 13    594491
# 14    649176
# 15    313672
# 16    351105
# 17    988459
# 18    505541
# 19    625142
# 20    440522
# 21    325157
# 22    345499
# 23    668909
# 24    912934
# 25    312851
# 26    184589
# 27    175061
# 28    587767
# 29    807040
# 30    175705
# 31    841857
# 32    993756
# 33    514956
# 34    499806
# 35    975392
# 36    476429
# 37    538946
# 38    574663
# 39    455675
# 40    452461
# 41    823085
# 42    498753
# 43    453347
# 44    367625
# 45    982408
# 46    927258
# 47    683374
# 48    611859
# 49    545900
# Name: otp, dtype: object
# (50,)
# col name and type: is_verified & BOOLEAN
# col name and type: created_at & TIMESTAMP
# col name and type: expires_at & TIMESTAMP
# ✅ Bulk insert complete for phone_verifications (duplicates skipped)
#
# --- Processing table: file_exports ---
# col name and type: export_id & UUID
# col name and type: company_id & UUID
# col name and type: user_id & UUID
# col name and type: user_email & VARCHAR(255)
# 255
# 0                hgarcia@example.com
# 1               eswanson@example.net
# 2          robertjackson@example.net
# 3               ylambert@example.net
# 4           eatonmichele@example.org
# 5           jacksonjones@example.com
# 6                 kara82@example.org
# 7            elizabeth60@example.com
# 8          bradleytamara@example.com
# 9              anthony43@example.net
# 10            watsontodd@example.org
# 11         pettyjennifer@example.net
# 12                sdavis@example.org
# 13              joseph16@example.net
# 14             caseylynn@example.org
# 15            lopezdavid@example.net
# 16                 jrice@example.com
# 17               cmurray@example.com
# 18        catherinejones@example.org
# 19           brewershane@example.com
# 20         aprilwilliams@example.net
# 21          scottgabriel@example.net
# 22             heather10@example.net
# 23                 jlowe@example.org
# 24       mcdanielanthony@example.com
# 25          jeffreyroman@example.net
# 26             theresa72@example.com
# 27                 otodd@example.com
# 28       trujillotimothy@example.org
# 29           alanaguilar@example.net
# 30          paynejasmine@example.org
# 31        schwartzalexis@example.com
# 32                nortiz@example.com
# 33        allisoncordova@example.net
# 34           sherrybrown@example.org
# 35         christianwood@example.net
# 36        jenkinsmichael@example.com
# 37           marcbradley@example.org
# 38             cookrobin@example.org
# 39            bakerapril@example.net
# 40          williamgreen@example.org
# 41            johnaustin@example.com
# 42       connoralexander@example.com
# 43             anthony53@example.com
# 44                zsmith@example.net
# 45         lorettawarren@example.com
# 46    villanuevapatricia@example.org
# 47        russellchelsea@example.net
# 48        browncassandra@example.org
# 49              shahjuan@example.org
# Name: user_email, dtype: object
# (50,)
# col name and type: file_type & VARCHAR(10)
# 10
# 0        equity
# 1         debit
# 2         debit
# 3        equity
# 4        credit
# 5         asset
# 6        equity
# 7        equity
# 8        credit
# 9       expense
# 10        asset
# 11        debit
# 12        asset
# 13      expense
# 14        debit
# 15       income
# 16      expense
# 17    liability
# 18    liability
# 19    liability
# 20    liability
# 21       credit
# 22        asset
# 23       credit
# 24        asset
# 25       credit
# 26        asset
# 27       equity
# 28       credit
# 29       credit
# 30       credit
# 31        asset
# 32      expense
# 33       credit
# 34        asset
# 35    liability
# 36       income
# 37        asset
# 38       income
# 39    liability
# 40       equity
# 41      expense
# 42        asset
# 43    liability
# 44       income
# 45    liability
# 46        debit
# 47       equity
# 48        asset
# 49        asset
# Name: file_type, dtype: object
# (50,)
# col name and type: status & VARCHAR(20)
# 20
# 0        unpaid
# 1     cancelled
# 2        unpaid
# 3      inactive
# 4       pending
# 5        unpaid
# 6     confirmed
# 7     confirmed
# 8     confirmed
# 9       pending
# 10         paid
# 11       unpaid
# 12     inactive
# 13    cancelled
# 14       unpaid
# 15      pending
# 16    cancelled
# 17         paid
# 18        draft
# 19         paid
# 20       unpaid
# 21      pending
# 22    confirmed
# 23        draft
# 24     inactive
# 25      pending
# 26        draft
# 27         paid
# 28    cancelled
# 29    confirmed
# 30       unpaid
# 31    confirmed
# 32       active
# 33     inactive
# 34    confirmed
# 35       active
# 36       active
# 37    cancelled
# 38    cancelled
# 39    cancelled
# 40         paid
# 41         paid
# 42     inactive
# 43     inactive
# 44      pending
# 45       unpaid
# 46      pending
# 47        draft
# 48       unpaid
# 49         paid
# Name: status, dtype: object
# (50,)
# col name and type: file_path & VARCHAR(255)
# 255
# 0     Per whole treat direction. Democratic that dec...
# 1     Ok share green let.\nEconomy enjoy rise now re...
# 2     Two kid senior design. Sense into should memor...
# 3     Far from maintain court picture TV. Number bea...
# 4     Drop realize difference blood safe. Quality of...
# 5     Land coach light point manage. Professional oc...
# 6     Chair author exist. Write contain stuff member...
# 7     About base where. Side memory fund skill analy...
# 8     Reality newspaper read general bit get. Speech...
# 9     Thank sister body home through. Personal win s...
# 10    World big control eye teacher represent ok spr...
# 11    Relationship draw condition couple thus. Histo...
# 12    Home indicate stop with opportunity direction ...
# 13    Similar it sometimes financial. Arm oil girl w...
# 14    Painting plant present government suddenly att...
# 15    Ago rise during Mr process. Room network us by...
# 16    Method place network either leave this. Play t...
# 17    Alone ground kind them. Discover describe fast...
# 18                         Though study what own skill.
# 19    History full social simply rate recent. Life l...
# 20    Professor until picture enjoy talk music fly. ...
# 21    Sense indicate cell structure.\nEvening increa...
# 22    Edge commercial Mr position to deep hit. Econo...
# 23    Decide order any source technology around coll...
# 24    These management official may they hold. Inves...
# 25    What investment order heart identify yeah. Adm...
# 26    Especially per seem stop national sure. But mi...
# 27    Worker meeting resource sister now hair ten. S...
# 28    Increase truth where investment glass. Play fa...
# 29    Success source statement exist fall. Drive org...
# 30    Already put write ball. Lawyer focus painting ...
# 31    Side level yet heart party stock spring. Wonde...
# 32    Five actually test begin another support. Ente...
# 33    Front she before note explain movie. Method en...
# 34    Purpose heavy exactly deep reason fall type. S...
# 35    Much former bar. Rule no moment fast forget.\n...
# 36    Call whether conference bag watch various. Rea...
# 37    Style company someone final moment worry black...
# 38    Husband room military concern move ok. End ind...
# 39    Physical actually follow above leg plant sport...
# 40    Fact employee light inside difficult. Effect w...
# 41    Administration very listen easy. Around your e...
# 42    Much if easy realize. Total southern throw aff...
# 43    Three charge fish happen traditional cold netw...
# 44    Discover fire difference agree health sport. S...
# 45    Various suddenly rise institution manager. Car...
# 46    Heavy feeling senior order. Scientist rock res...
# 47    Tonight treat guess once kid all. Particular s...
# 48    Everyone international end rich.\nTeach left b...
# 49    Notice call husband physical. Yet order public...
# Name: file_path, dtype: object
# (50,)
# col name and type: requested_at & TIMESTAMP
# col name and type: completed_at & TIMESTAMP
# col name and type: email_sent & BOOLEAN
# ✅ Bulk insert complete for file_exports (duplicates skipped)

# %% [markdown]
# ## v2 code

# %%
# Persistent conversation memory in Redis
history = RedisChatMessageHistory(
    url="redis://localhost:6379",
    session_id="user_001"
)


def extract_sql_from_response(response: str) -> str:
    import re
    # Extract content between ```sql and ```
    pattern = r"```sql\s*(.*?)```"
    match = re.search(pattern, response, re.DOTALL | re.IGNORECASE)
    if match:
        return match.group(1).strip()
    else:
        # fallback: return the whole response if no fences found
        return response.strip()

# Load schema from Redis
async def load_schema(redis_url: str):
    redis_client = redis.from_url(redis_url)
    schema_json = await redis_client.get("db_metadata")
    await redis_client.close()
    return json.loads(schema_json.decode("utf-8")) if schema_json else []

# Agent 1: NL to SQL with follow-up support
async def agent1_nl_to_sql(user_question, schema_info, llm):
    # Extract last SQL if any from history for context
    last_sql = None
    for msg in reversed(history.messages):
        if "[Agent 1 Generated SQL]" in msg.content:
            last_sql = msg.content.replace("[Agent 1 Generated SQL]", "").strip()
            break

    schema_desc = ""
    print(type(schema_info))
    for table in {col['table_name'] for col in schema_info}:
        cols = [c['column_name'] for c in schema_info if c['table_name'] == table]
        schema_desc += f"Table {table} (Columns: {', '.join(cols)})\n"

    # Prepare prompt template supporting follow-up
    template_text = (
        "Conversation so far:\n{history}\n\n"
        "You are a SQL expert. Use ONLY this schema:\n{schema} and also keep in mind that it's PostgresSQL, generate the SQL query accordingly\n"
        "Also take a decision on your own, where the question given to you, requires to be converted into a SQL query or its an normal question\
        , if it's a normal question in that case, reply back to the user without converting it to a SQL query and calling the second agent\n\n"
    )
    if last_sql:
        template_text += (
            "The previous SQL query was:\n"
            f"{last_sql}\n"
            "The user now asked a follow-up question:\n{question}\n"
            "Please provide a modified or new SQL query that satisfies the follow-up.\nSQL:"
        )
    else:
        template_text += (
            "Convert the following user question into a valid SQL statement:\n{question}\nSQL:"
        )

    prompt_template = PromptTemplate(
        input_variables=["history", "schema", "question"],
        template=template_text,
    )

    prompt = prompt_template.format(
        history="\n".join([f"{m.type}: {m.content}" for m in history.messages]),
        schema=schema_desc,
        question=user_question
    )

    resp = llm.invoke(prompt)
    sql_query = resp.content.strip()
    history.add_ai_message(f"[Agent 1 Generated SQL] {sql_query}")
    print(f"[Agent 1 Output]\n{sql_query}")
    return sql_query

# Agent 2 and 3 same as before (validate and execute)...

async def agent2_validate_sql(sql_query, schema_info, user_question, llm, max_retries=2):
    attempt = 0
    while attempt <= max_retries:
        attempt += 1
        try:
            if not sqlparse.parse(sql_query):
                raise ValueError("SQL parse failed")

            table_columns = {}
            for col in schema_info:
                table_columns.setdefault(col['table_name'].lower(), set()).add(col['column_name'].lower())

            sql_lower = sql_query.lower()
            valid = any(
                table in sql_lower and any(col in sql_lower for col in cols)
                for table, cols in table_columns.items()
            )

            if not valid:
                raise ValueError("Table/column mismatch")

            history.add_ai_message("[Agent 2] SQL validation passed.")
            print("[Agent 2] SQL validation passed.")
            return sql_query

        except Exception as e:
            history.add_ai_message(f"[Agent 2] Validation failed: {e}")
            print(f"[Agent 2] Validation failed: {e}")

            correction_template = PromptTemplate(
                input_variables=["history", "schema", "question", "bad_sql", "error"],
                template=(
                    "Conversation so far:\n{history}\n\n"
                    "The SQL query `{bad_sql}` is invalid due to: {error}\n"
                    "Schema: {schema}\n"
                    "Rewrite the SQL so it matches the schema & user request and also the syntax of the postgresql:\n"
                    "{question}\nSQL:"
                ),
            )

            schema_desc = json.dumps(schema_info)
            prompt = correction_template.format(
                history="\n".join([f"{m.type}: {m.content}" for m in history.messages]),
                schema=schema_desc,
                question=user_question,
                bad_sql=sql_query,
                error=str(e)
            )
            sql_query = llm.invoke(prompt).content.strip()
            history.add_ai_message(f"[Agent 2 Corrected SQL] {sql_query}")

    return sql_query

async def agent3_execute_sql(sql_query, toolbox_url="http://127.0.0.1:5000", toolset_name="my-toolset"):
    async with ToolboxClient(toolbox_url) as client:
        tools = await client.aload_toolset(toolset_name)
        run_query_tool = next((t for t in tools if t.name == "run-query"), None)
        if not run_query_tool:
            raise RuntimeError("run-query tool not found")
        

        raw_sql = extract_sql_from_response(sql_query)
        print("SQL sent:", repr(raw_sql))


        print(f"The correct sql query: {raw_sql}")
        tool_call = {'query': raw_sql}
        result = run_query_tool.invoke(tool_call)
        history.add_ai_message(f"[Agent 3 Execution Result] {result}")
        print("[Agent 3] Execution Result:")
        print(result)
        return result

# Orchestrator with follow-up support
async def multi_llm_pipeline():
    redis_url = "redis://localhost:6379"
    toolbox_url = "http://127.0.0.1:5000"

    # Load schema info once outside the loop
    print("Loading the schema info...")
    schema_info = await load_schema(redis_url)
    print(f"Schema info loaded. Type: {type(schema_info)}")

    # Initialize LLM agents once outside the loop
    llm_agent1 = ChatVertexAI(model_name="gemini-2.0-flash-001")
    llm_agent2 = ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0,
        api_key=open_ai_key  # or rely on env variable
    )

    print("Starting interactive session. Type 'exit' or 'quit' to stop.")

    while True:
        user_question = input("\nEnter query (or follow-up): ")
        if user_question.strip().lower() in {"exit", "quit"}:
            print("Ending session.")
            break

        history.add_user_message(user_question)

        # NL->SQL
        sql_query = await agent1_nl_to_sql(user_question, schema_info, llm_agent1)

        # Validate SQL
        validated_sql = await agent2_validate_sql(sql_query, schema_info, user_question, llm_agent2)

        # Execute SQL and get results
        results = await agent3_execute_sql(validated_sql, toolbox_url)

        print("\n[Final Results]")
        print(results)

        print("\n[Conversation History]")
        for m in history.messages:
            print(f"{m.type.capitalize()}: {m.content}")


if __name__ == "__main__":
    await multi_llm_pipeline()
